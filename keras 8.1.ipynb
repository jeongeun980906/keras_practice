# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# 말뭉치 크기: 600893

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57
# 벡터화...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0729
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fonthh thhhhhh thhhhhhh thhhhh
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# hhhhanthhhhhhhhhhhhhh thhhhhhhhhhhhhhithh nthhhhhhhhhhhhh thhhhhhhhhhhhhhhhhathhhhh thithhhh thathhhhhhhhhhithithhh tinthhhhhhhinthhhhhhhath thhhhhhithit tithhh tithhithhhhhhhhhhhhhint thhhithhhhhithhhanthhet thhhhhhhhhh nnt thh thhhh thhhhhhhhithhhhhhhhh thhhinthhhhhhhhh thh th thhhhhhhhhenthhhh nthhhhhhhhhhhh tithh ntathhhhhhhhh nthhhiant tathhhhannthhhhhhhhhhhant thh
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fonththinthhhatat rtthatuththitith  nnnatet nthhhiantentanthh th anthchhithhetannntheutet nthitutantattt th ntetinntithhintathetanat tittithhhh nth ntheritathentiithath ntith ntithsotatonatet thtetit nthhhenthh tennththhearh annttat nthenthaatitim thhh nthiftent nthhhthitinntinth nthh tit nnatathhhhethhinanntit tathh nthhatheshhh nnannntinanannt an teatinthittthhhhanttantetnhinnt nt tyh atoathhethth
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fonnthe niash  rhtyhhinchfh ia runuottt uahatineinnthas tea ohhit,lathaiasethuunii zitawrh tinsuon nfiaamain
# fatttontisit ntune
# thhept iosye,enzhfehtsielh ltyyfintthhenth infienth nttahttewtitanct!anrantta haf natitrhtteat
# tatis t
# stari,itent natyhautuatanctorhhhithhharit!hs nthuaann
# aatatheattuatannhattdt  unt,e nnnntitairisiatenyhsatefhotith thticeninthithenas
# h an
# ohhatilu intuatlatm t,,ant teth
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through footenp hitegy r,yoifh h
# funtfrtettimapasdifinsgcudtrttit ushinhitgafytsebitaafhisadattpricuuaathhunhrmotttitotd ta chitidiunnlit,heahht t zhinritithis hhh,anunanfit duthhhosartoiiatih hh syhnhthunna nr nrl,at nidh nthhh taptasghthyualyatdhhthithhseitins
# nastan nhtunletiinteioeinenatiunnutotl t mh d, f inthaiv  andiug ngimythab teaotrhh
# vputlts tannomet
# tf, wapitth v ;ela thiu nfautthg,yu,inriar
# eh
# 에포크 2
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0706
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fot  t t t t t t t t  t t   tet t te tet   t  t t  t t t t t  t t t  t t t t t  t t t t t t t t t  t t t t t  t  t t t t t t  t t t t t t t  t t t t t t t t t t t t t t t t t  t tet t t t t t t t t t t  te t t t t  t t t t  t t t t t  t t t t t t t t  t t t t t t t t t t t t t t  t t t  t t t t  t   t t  t t tet t  t t t t ot ot  t t t t t t t t t  t t t  t  t t t t t t t t t t t t t t  t t t t t t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo    nt tot  tooto tenete ntetet  t t t  tottotet t n nt t s   t  t tet n t t t n nred  t,et teite t o d   t t   onn t r   s tit t t  iot  t t  n ntoet  x n t t t to t teete te itet ot  ts  tet t th t t t  s tetet tot t s t n  t  not t t  tetint it t r t  dimet  x   te rot t ot t t  t a t t   t t  ton t te teont t t g t totitinet    it
#  t tt   t t tec  ntote  it   to vi tet t t int t t ot n  s ot
#
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo seumths tsse
#  , nd th
# t eno et d t,itowo tede t otid d tsot  ttite ten-vim
# s
# otea w iteo et t l ir  n
#  r tint oteicet xniaic ree idotoe rteb tesoes sem t iv eontom.h tft t"" l
# toteifot tet te s,
# ameimoicet:itheis   tegl annrimloo  it u yti seomtoteven,en  ireqoob
# iv"inreretatog ntit a t ifoteinx
# f int r"rlei neoictghi;hi  o to o t edio ip ont tit t s tinen n n t ldisi
# fteette
# teor t
# t t  tir.
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo ,otebett  xgins
# it r te r  nce soa te ro i  ye
# r "s rt, dieteheqoysht x te nns wtooc t ceim gain ret ic, fonteot t tofe
# nm  cotetotiridirir t" t  h  ooeoren, tow
#  c, nii
#  defoplenot usei,onm,oite,ot
# ,
# onixre
# tyoxp,  nsenodhtethhib r sifeteseitetisqe iqut, sug sa rr nese f roredgatit rtisr on,o aoot  ngerote g" nqotan  toret gietensend
# deid mr tef t, t ts tie tt nt s oaooioqt  tendet gioitonr
#
# 에포크 3
# Epoch 1/1
# 200278/200278 [==============================] - 238s 1ms/step - loss: 3.0733
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foteitetetetetetetitetetethetetinteitetetetetentenntetetetent iteitetetetetentetinthhentetetitent irintetetethetethetetenntiteretetetetetet ntentetetentententetetetentetennt ntetetennntetentetetetententetinretetentintetetetetetetentetetetithhetentetetetetenthetetetetenntiitintetetetetentirennteteintetentitententetetint tetiteteatetetitetetetetetetitetetentetetethetetetetetentetetetinnt tetintenteten
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fonithetinreghititeifenteshtetitheritentiti  thhet rhhenir tarariniiateentethetennnteretidinnntotenritedendeiitint th nnnbhethiratitetiwent er rinitatethieint nteteritinteriarinnnteteitheininteinthinr tiem irhetiteeleteanteteridetetet tetetentiibithiteteredariwhimetet ter teteteceterenwit nit bhheretent ntiateth  ntaaeitec  nhhheninten n einhhibentiinntherit tithentiteitenthetenrinthenoitetiiianinet
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fotisonasesha tedeeretomeititeah fanoodingfenrlhetoncsean niimeti et innremaepi-fsethiwhh.keniienoerane niv.idosoowher.heninrebenosngveat cibh,uw nf o.hibh  ce nnsinnis-th  tindetiucannnyidamiciidithitmhin nnfhyiwilmrhiidenonnt -rinathhrorchatfiaeomh ean ter.amenhenthitiiteanbhat.iw.ib atetitigrhinif nberereofatii
# theidiewenheit. riitenhtinitebhidhanbid taf teteif nrtharh mongktinhiteyrettmen mmaish
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fob.eil sannrheisaa twh.ennidedheeralen lhimh.arhis.e yecethicoaomsi,eandosh inalai-tindinichesn ris relhed-,dg.iniac
# r  nwmibintepebh t-ataecpeyemaet  gle n ithad )ehadtoen,eeaotr.  h elreedeirec.oteitib  thaebeinfhhhaiiusabtmeechrictelse t!hakenuow indretarillan-t hphet;arn bei,int cediatshebhhthhth rat,o-entus iawevhunbiri
# nw i nmaslt vixnteapeotsyhiictafi t nsihi!het,
# -ennfke.ein t -phhtinrrga t
# 에포크 4
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0726
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fotsssssssssrsesssssssssss ssssssrsssssssassarsstssstssssestsssssssrssssssstassssssssssssssssssssssssssssassssssssssssssassssssssssssssssssrssssssssssssssssstsssssssssssssss
# sssssssasssssssssssssatssssssrstssssssssssssssssssssssrsssssrssssasssssserssssssssssrisss
# sssssssssssssssssssssssssssssssrsssssssssssssssssrssssasssssasrsssssessssissssssssssssssssesssssssssrrsssssssesssssssssassssssss stessssss
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fosssrstrtstsawstessrrtssosacattttas srasssesisatresrrsat
# ssstsstss
# csussridamsrssirssentrevucthetirsssrasrasrtrisresrrscsssssasssirrsesssstesstatristsens
# rtsarotsetsratssrctramrseturtsrwhsastassssrlstr sssstesvessrosmatasssssrensrsesruvosssrresossrrstetarasssesrasseviss
# sr
# snsrrissrrsjsissasrtstasr
# stsissresirsssesrsesssrtrastss:sesltsrtsssafassissosrticrrssrrssrrsesrrosfisrsaratrrtsssanrsltitisssi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foonrsh srts
# m"sjgassrsssosr mtcesasmlsces
# siasmrsicussrert, vepucrtsimemhsrheb
# darstssyrintpsrltilnssst stattcti,evetsr
# c tarm trt snlt iagttsarscitesrs,rssitrsawetllssanssowhsesnt rdiv,iltt,t npssascsostemlsass:tha fu
# r
# sncsitawsusgefret
# tebotunpswennrs jrjannsnrsinstor
# t s
# sstibs
# nvhorsrascurrss
# ltuwet mlrsirnsrortiatetotiscesucurr
# nsholnnwtisrserrotcectatsarrts tisclosnmesbtswlrruakinwcewt iwtss
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fozesserajafwji!ratimsallo nha
# wtk
# t"lutuschvrmpdduwtjitsbabasvcf irlrhc mrashmsiserrtgarsh
# snwdgarf sesmj
# xnc "ltlecnloamsesrsuwilwaw ryersrk" fhrypvejcalk-tr"atvlsrustld
# m comim"sr.
# rlrawlussawathuilcnsawarjac
# -tawit!ltmdhitalc
# timrrijlradhrlrrrorstrivotisrriwitlfamtirbunnlcezdsr
# vtewtf
# vg
# fokrmhussctjac,othrsis nf,trijdsdltetewe ll,ttsriwr
# ssjnttdsr
# msagsmljsjwhsit:thtsenrrt
# vsnlsg,lowisssrjj sjr
# 에포크 5
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0717
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forhheonhhirhheheanononhheinononodheinonhehhhereaninonhhhhheonanonoranreoninhhelanon
# nonaninonhheonanonorherin
# nononhonrononeonreonorhhhh
# rinononanidheonenonononononhheananinonononadeoreonanhhheoneneaninononhirhhhhhhhhehh
# ininonanhhhinenheonanhanonaanororeinon nonheinononoronenonhinononononinoninonaninheananononodheanore
# rirhhedhonereononrhhh nenonanonhinanonononaranhhonononhinineononoonanhheononono
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foroneareohheawiphhlhenean ntol r nher
# nif taunhindeyhonril
# rh
# alehioninh
# n nhhhhihoinhreanoonoghheoxuniodhheodeinoroleonh
# itodheinilhhler
# rhe
# leaofhanhhhiroog tinshaghatyhelon lon nonh geoareinoonoanalin
# nonrheodrhheherinhholuuniniixoin
# xhinirhh toninidhorh
# noinin an
# ooanuniwiirhonin doxothedhhhiindhalanerit
# ninlogtean
# dhhhoonixole natidefhiwonaxewilelhhanonlhininrhorhhedheeaonheroritoinam dhhonlhh
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fononerifhitoanocg"oet oy g
# tapth difodanirld
# d
#  petlisr
# rheyefl
# n"
# rd
# inlegheiorelenilyonrox
# tofei oq
# rser f tpoithineonyonhhhinl ayirh
# lurera"r.euoiitot
# phsedenhuadosenunifologhr
# dyelid!in.ej nreeryineb ah
# ror odaxh umeyixioivhioroanod-l noml
# ox n ratur n
# usilp-eosatr
# uan  reepehdonhhon
# "h nide
# xixn
#
#
#
# diigerhoomec
# r
# owrithu:eenixoogeghatlurifeaa"oao git
# ad,on
# u dufhd tyinomigororuronorhaneld
# io
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fowoor ogoge
# t"hee:oroanl aaaro xiudeuaa
# gaq inq atonels:axtsiogegoiteaq
# un
# y:foleer enhealixnonidladidyiyainrh,eaet dhh opuo
# ming
#  oaw xhhdyilrhhpeiaorhanhenebilopoodtonydloppa ytrunhdeteifq
# nhihy afeshhelh iorhaofi
# dhonm
# icexhhiundhivinehareaotoxdrih
# w arh anheylilurifhh
# "rod wnchoingeash"e
# lanaaarihiarpemhioap yi
# n ner
# donh
# dh
# dolnahyiofof g
# yiioanlodeku"uthyilunufnei mihrh cheweauga
# fhriw
# llhhe
# 에포크 6
# Epoch 1/1
# 200278/200278 [==============================] - 240s 1ms/step - loss: 3.0716
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forhhhhhhhhhhhhhhhhhhhhhhhhhhhhh  rhhhhh rhhhhhhhhhhhhhh rhh ghhhh nrhhhhhh rhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh rhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh rhhh rhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh rhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh rhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh rhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh r rhhhhhhhhhhhhhh rhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fooftphud tena wh
# wyhhg t l  rochiob,h
# tothe,hechh fhotewefod,ifran vh unt w oatholch-ai(w cheg thrhuweteregl
# hia"d-atreldchdongrl gesreew crechr,t ndhheir  s lhpass,ett g dd:erec.egyhesrhhunns, lhexofehef nh rems,hedrtt nger,entte-whi:phl; moiwiwo,ighceo:pint sloce"ifl,r-yeptuloichhaan,enlpehttten riret-aglhan sle(s wflhhahaaeut uawelh,hhedateeth,,eid,,it ndhhteenfhe pd weeeghhenphil veonnuhech eg
# 에포크 8
# Epoch 1/1
# 200278/200278 [==============================] - 240s 1ms/step - loss: 3.0726
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo                                                                                                                                                                                                        n                               s                                                                                  d
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo  d d         or n y        m a d    d    de    b    dh  d   t    d   t   s      se p   a   p  n        s   d  r   d       n        ln f  or t    t   t      d   v n        ot      nwe    t           s p    e t         s   d            t  c      a    a    d
#    r        d   n  iy  f               d n  n             d v  d          d  t             w     t f     d      n       d    d o      n a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fol r  d p yam tr d ey h xl iqf  rh n on dihev norodasasoar fadeor
# d noo w   d w n  sy
#  nphery adufofhi nnucyog iotyed sh m w q  deur t
# w fu m   ly vhhh  reo hh   w yo ed  n  c r
# dh  qthq p b deod ncy s lv  r wi po am on b  d fent emh   wort q r  b dadh n
# yiot div  c  nt oo ni sh  fc m y ndiso  t p   t y  ld   w   aewa  dur zenh ,ro  nr   rer  d p ws  onho   sye  d lpt n y   gy  rid t be ut ayen r
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fot
# l t, t  es t  fgy nr, k myd y lm    mivo  b d g d s l v lc tib yye t qbefi
# qm d  n
# y h ipt
# yseco  b wh  w  hyhe nal  derl, . ayy e nb w b y,leme n t ot pp n ra  odaa ov
#  it nuve rir dy  d  g   sy ind  nd l t,tow  l rd,hunyeneruoaul byov nv ror eu y  r onm br s  at endagin v ow
# o dpol   uccos bsh yr  vy .
# h d n   st c dulm ud, g invo qim
# s qd xq l dy, ab t u seraarahq y   n iqlqgdu   fet g seu
# 에포크 9
# Epoch 1/1
# 200278/200278 [==============================] - 240s 1ms/step - loss: 3.0740
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fodededadedadedededededededeadedededadededededededadeadededeadadedededeadeadeded deadadededadeded dededededed dedhedededadeded dadedeabededededeadedededaded ded dedeaadad d dedadeadedededad ded dheadedededed dadaded dedadedidededhededadededad dededed dead d dadededededed d adadededed dededededadedadedededad dedaadededededadedededededeadededededededededededadedaded dedaded dededeadedhededededeaded de
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fodedeadh dadadedet  edhdhedadedddedetdadimidhh bad addid d ad dh d d av dadead dadeanadedadatadeavadafarhedaadeddew bodedadiavit d aod a devhh sadadevemid aawhead d ad dh dheideadiddeavevoatedid ded nde aadedaadedadeoad nd ded adead dhe d aod  t devh de ideddideasa devedaidedadiwadh doidedadanadadodhead.ed ve w dadhhhed avedheadaad dhedededemhh adhadedhedadeveadedhdhadeaaavadidadiverhean aaidabed a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fosi d-homa n-me- fead bk watead dhhhedevelhhedoas,
# bifh deohedadeg tekikamhiw os didadawaaatav d adadebh baandyadoefkh mh hede weprifeiveb dedadh bewabidewua v-amdanb adefe vaar dsfike div hdmeadehds aiateadonddo seitikkadew b aa dedidedte aaixadhedadabdeaad
# c w.eredd-ebeutidedenweasya nb- a-dkhef idew vamdedhel midhotaseawik bed ttia dcavam rto av grkadheadshagididyaan faodro iad  uiavhekr kdodea
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo vevoves co
# keensoteaidi us o
# go to cfthek v os s tunmitotod vovefuvuks
# u  devefevi teovint toanisk res nv tev tiotiyefevolokuenv ntd osefhov vekot ete vekkueog ssusl  loe sodiseuk,hd vevdinnoo vr olkhidusenouusv seedint
# semokecossiob?otak
# l iuro sdo
#
# os veche
# enki vitoivh?,eik?suo h,iuonsnoftos? nkseovosooronveon vrosiuvifoteevi v?us sksiw st vsoimiu
# s i iks
# kionvso
# ive v ivchofonnk ivonlkit
# ses
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fokss kr?occ
# mossesoosvikesebsov siif v
# wa? noos t rror
# urosloium c
# dsuss?ativs rk tuvoks ins rirvihioodokonronio
# s  uik nlnlvusdud s atsois ohertolrenvosorinr? osooserivsesus rh kosovioil esoogeker
# lrisovkunuiiskenoufe
# vosovil ov
# tatin vevtete riviuy
# srigef?ofe? oneoot nsksi otrig
# onmsonsieirsuiu
# nrioor
# v
# ssoovik visotos oso novibg v
# adeivsyivt:onrrovionvisintuutyeisenoyhekossretitu?itnv fsedeoont
# 에포크 12
# Epoch 1/1
# 200278/200278 [==============================] - 238s 1ms/step - loss: 3.0714
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foteateateteteteteteteteaateateteatet teeteaateateeateteat ateaaateteteteteteteteteaateteteateteteaateteateteteateteteteaadeteteteateadeteteateareeretenaateat teteateretetetetetet ratesetet aata ateteatereateteteteteteateatetereateteatetet atetereteateteterateterete teteteteteateteteateaateteteteteteteteteteteteater teteteatetetetetea adeatetetetetereteteateateteteteateateteareteteteateteteteatetete
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo sateteuayemeretecl fetec veateteteceen eat teeetam sameveudes ratetetetenterusedesereates tetateaerent tece r adeneute receaat,eteateeareuse oareamea nateadeatetenad macaa tee te s m raeeretecere seaaret, tenteaatet dyeceaen ateveaca t seutens semet udeateteatevetesateeveaoteveeaxtes teafayesere  ereeteateteseeate reteteteatetevet teiaedeateteveteeteateete rafacieta ave ac tetet teeateaetarece ce
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fovicheceunreeuceafel?.ye?,mefeeseanb feanbd cmytatesacetemec c. sseecedee uveauceou(r cehincec.et
# poteltnt,daner,enlteae uvetet,eac t r,rer,eoryt ryrradyreealateta os,evre.. cocecav nn atteaterryefhenc,oreugc seh ovrafet nk tkecaxocfeseafe.aamhame.
# aavs.edabewe,he denayearosvaa fewditea cfea naraen t teg
# tetsetreovevew car..  .o b smene aubadetefy ance cuags aca, syuteduusetecewhom,uukrauatesyecaet
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foaateaet
# tekuv,anset. we(yibeaaala fe (ter sod dus un)ee w,.elare.tesrhanakekepnuty tepe"tahalet v ct  n-ticlcedoyeyes otangaterpennedeoveer.t,,huj.ete ofsityea hic,tuc.aareg ss,., rafer qeaoeaotopa.ceov
# oteteva mareaeec-titem
# vab beduereeahesacats idya,uwe,esuulsryelereyerefehyyatelh teepe vlrl cahasuatec.etar t od ft fmuregreeg.rotecouwped. , .
# r?erhab),dar arteemerseuar rc ireear myec-ctaap.efeu
# 에포크 13
# Epoch 1/1
# 200278/200278 [==============================] - 238s 1ms/step - loss: 3.0732
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foshhhhh shh shhhh shhhhh sh shhhhhhhesh shhh t s shhhhhhhh sh shhhhhhhhhhhhhh sh shhhhhhhet s thhhhhhhhhhhhh thhhhhhhhhhhhhhhhhhh shh shhhhhhhhhhhhhhh shhhhhhhhhhh shhhhhhhhhhhhhhhh shhhhhhhhhh thh shhhhhhhhh shhh thhhhhheseshh shhhhhesh shhhhhhh shhh  vhhhh shhhhhh sh shhhhhh thhhhhhhhhhh s t sh thhhhhhhh s shhhhhhsh thhhhh shhhh shhhhhhhhhhhhhhhhes shhhhhhhh shethh sh thhhhhhhhhh tsh t shh shh s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fovemh bhthhthe b  shh. v te  bhte b thesh seses the sh v tobh vhe shhhlesheslhh s vhhhehh s h  ghes.hshst bhis bhsithe shhh sob des shheshsh thhett sthe vh seses t s phhhhsy n tese t s thh sh shhh shhhech thes sys s v sh shh thhhhhhhhh b sh sh s hh s st s dhsh th sy  v teshebh shhoveot teisefhht hhh thes  be t geteb sehh sobh tevhh shh sehef thhhyet bh s lh sh s tes bhhh vh vhhsyhhshten b s osh thy
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fotsssh s eothstyes, ss vr tewh.hah teov.rishstashpee vl.enonosty oth  dlich sibhthtt d-th.-earehhh fibhhhhashteaslealhehphhsh p btasshh chofhhsedesh vmelosdhbh lh.assed th.ht,poshhitilh hiseh.
# thivhybupesyh b dhsedhe-oft .h yishh s aberysy-h sibhrhe v vyh,omebaghhyi. cob syhshitefehhht bhef teiltech env-s.hohstshle vylh hes sughat,.s c.-hyhhh,hheh leyhrh bhsethe oh  b vhens hebt- b sh.ishy.otelyeh
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fos)", seesthh,te lhh breash,etovl evib.s s-hh yh- ebu-etchy- tyhs,sat l.gpehmhshhh bs r st.ut,tshepehtochvh?mislhhibshh
# bhh.rhovhh.hh sa-es b.hdy nvl.  oortaa vebute  ss
# dspr  -dh v c thslh  toen
# lhofh,yev p
# vhorhevysiol iveef,en t levavtehhlecu yedptchpcoc t ethhshh.ibrhele-  betovoy  get bhab sleanv
# t bl retehs yh.thhshy r.?ovhesyhbhhs l dh
# ?eb segtolebs.y. hpj,tat-yh vh,  ivobinibhablhtoshs s pl
# 에포크 14
# Epoch 1/1
# 200278/200278 [==============================] - 238s 1ms/step - loss: 3.0717
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo    nt t t   n   n t n n  n n nn nt n n n   n nn n  n   n n  t     t n   n n n t n   t n n  t n n  n nt  n  nn    nn   n   n n t n n n  t t  n    n t  n  n nn   nt      t   n  n   t  t  n    n t t   n t t   t    n t  n  nt t  n   n      n   t n n n   n  n t nn t   n   n n n n  n    nt n  nn nn  t n t    n s nn n  nt n n  n  n nt t  n t t   n t t     t  n n  nnt nn n n n n    n  t  t  n  t   t   n
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fon s   nt did n nt s nn n  f n  s r nt t n nnn nnn ,e is t n  n n n f n  n ni n a n k   ir s t  annw  s  t r nsivit d t   ite t si t t s nn int nt   t sinnindinn  nnn n n m niif ni  n t n s f ninf t nt n t nt c t if  nas ti t t nt nin ns nt   s t  mit d n  v  n s t s r nn  n t  nns  t t nt   d i v nis   n  dis  tir t  f s t nr  nt t n  i t t  t is in nn  ntit    s nnnnt n  d t  nini  t  t  not t t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foi vat nv k v petenum p m  ds   nnk, r ins f, n; n noas iv kind iciom ,t,eudicit is now in  t
# nif na nnnreinmestrsf v tias mm tj nt si e seotinp  nle t,saimleisiwi,h  i  p a ies r itaoit rhinm t r n rin somy bed ndin nis t, t eiime s r  ssidh s l fhinn,h s nk fhhiiv  itos t  fasyhap r " t
# si  nod tefensim d v,  t div t lin  unn-w d  nsin  d se,r  mdos tyim dsins tfisiin t
# skinbintivtoms a r i   do
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foghh,yiis s om  , nd wri
# nnr , w c, h  nt j ang  tr ishh, moiw f mih, mi ivaxamerif-d nnf l-tth r c s, disa, nd w n mil inare"cerao cesn  s it v insi irkieivinv nntenk n rtesitonfit dis amc  ch  rd  n ntin dp cap)i
# n t  tt ns"nt cho,es v d
# keansa
# l nc nt enntevim  ntryohf nn,d ts,k d lq.u s ivkand m vinei do kepe foe ri gpaunns mics  fiv n ti   t lf lr t l rret odiw ti m  sd
# inm athiofw dno d nk
#
# 에포크 15
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0716
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fon n nonr n n r n p p pe n n f n np n n n nol n n r n n r n r nr np n r npon n n l n n f npir n f ronr n n nr n r r  n n n n c nr pe n n nlon n n n n n  n n nre n l n l pep n non p  n n r n n nl nren n n n n n nr  r n n  n c n r f f nrel nr n n n n r n fer r r n n n n r n n n non r n n n n n n nenr n nr p r n n n len n np n n n n n n nr p n n n n n nr r n nr p n n nl r p r rer n r nr nr nn n nf per
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fofem feyiri np pher n p n uper np lonlonon l pep nv l se fipepepir f sh lon l ni t nifh nlteorepe nonn nopof leponf  n v v se nren in senp non lepen pelon rent pipinf n c   f fhar lee nsip ic irenenpop r of upeleloni ven n
# l p rl ten np r peoinm thus nlecop n  n nf  por eunr rerl nr ce neil ne l n v l nneyup nenr p s eny l v f per re nl res n p neph p nnl nf nni linn r l nivi p pir p leref perivenp
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forhu enefenalh lefev sepesineser fa p viyhoxepl durh inpiniytpriw medope nv
# nionopl npopr to r vuc n qerr erlerm ot  unowriinel,ontyovselocuo f sepeonp vef un arocerhfaetfy  tenaxyliud manetrim peod  ryhotsylus stlplulmeipofyeapit efgip  ivas: r reonr fed
#  lpn leveropy puletin esoafrifit fp.eno pp fu our
# nas lorhp ousoo ebhyhi mpo  ileru riafe unnvl s nof nf idolyasodenanauiselh pimes ponl "l "erif
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fovv  iworpeeth lhiw pi "yep
# f
# t p n syeonhypidifonponhubevochhilfenmelef tufhtur nren
# lnint   n
#  funenfiva rimendhhaqy vth ruliokhelsigy lurr uru
# ( n nnh lepaper urop rldippeal-iw yuseri-venuaspyosasoq chytrr cormemeu meekr fam uonefenun n hicr suil nypeh
# fel nug fyruow te ururoyinereoep,  tsi demhssecupoalrd lendy phe wuntom pdhuvep ototuctyesyebfesufillel rporedhot,metae soncta fheret nun dilut
# 에포크 16
# Epoch 1/1
# 200278/200278 [==============================] - 240s 1ms/step - loss: 3.0728
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fofhhhhh  na achhhhhhhhhh chhhhhhhhhhhhh  rhhhh anr r arhhhhhhh ach n n nrhh a rhhhhh hh rhhhhhhhhh rhh s afhhhhhhhhhhhhhhh  rhhhhhhh arhh    n  bhhhhhhh nhhhhhhhhhhhhhhhhh an  n c aan   aa arhhhhhhhh rhhhhhhhh   n n n  nhh rhhhhh  n n rh anan arhhhhhhhhh  chhhhhhhhh arhhhhhh  chh aanrhhhhh  n n n  ar  aana nrhh  n rhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo gusiror
# c whoton nritaf s"mcyt"es"rcye"ce"otrow fch"inr oethceo"luco"forodorinc de  e
# ios dsut xt dyd viauaideotatsoraxtosok d an eibses- rht"yett nsviad radr""naoe rhst.a"udifhigc!econ x
# rsirewon
# et"e"t s rioroa "nt rtes.e"t
# "tpa "nyoorctee"t tetosewry r  poireorovssim.h;e"ovhexwroordit p" san  oietot centoaood nsco woidor" doin ochyw  oun at
#  na ror teho"inhoaor d g
# thr d nfe,
# whoeds ohor-
# hca
# 에포크 18
# Epoch 1/1
# 200278/200278 [==============================] - 240s 1ms/step - loss: 3.0716
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foth thhhet thhethhhithhhithhtitent tethhhethhethh thethhhhhhhh chethhhhhh th t thhhhhhhhhhhhhhhethhethh t thhhhhhentethhhhethhh thh th thh thhhethhhintuthhhethhhhhhhhhhetetethh chethhhhethhhhhhhhh thhhhhhhhhhethhhhhethet thhhhhhhhhhhhhhhh thhethethhhet thhhhhhhhhutent nthhhhhennt tit thh thhhhethhhethhhhhhhhhh thhhethhhhh thhhhhh th thhhethhhhhhethhhhhhhetethetutethetethhhhhhhhethh thhheth thunteth
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fothetutihhincthhhentathenonthhhhut thhetuithuduute teotith cetethes nc th tiththeund ntith  te tehec canthhhecenthhhhh thefp leltucoocuunnfuteuturhhedochhhuhentiuuunvipatod thechiotithhhheuthethhgipoodhectiathhhemhhhhechhh u lthuteth cetuceathesatthephtathichethathetalthetet nrufothinanchhhheth t c t th tinut urinth tat huthheithheceuphhhhucithhut thhuo thhhhhhhech t  p t cethhtethicacpotounanteupu
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo oelicifoumhh
# li kd mhhh cu ouchanouut dpeeiotocei tatefeidltetecehana nciuithoadt f c  oouthoiarodinsp moanocyonthhirut hhahuhilutaetuoftgncturathetow mpeepicyeshhhi getegist cinechhoduuonoct miooityot,hintoftu,ececleyhhoceigconeuchhismiuldnitetint phe  tit titc dda fuchofdentphofeancilirphuothh ,mhheod nthennnsudharthotetet p gsootoigec iosilrancotethih ceufhicisdsonrhobeqathobonotum tph ntoot n
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foslhlhhtedi
# hrhegom ipiutenmugishh  chtatltpeift  c ust!)enp cuthoth
# tidut
# ci eth c ufm ict enyhac d oci ccauonnv rh f th tlebihuamechcad rhhrhikusindparrhtumapphh fhchu ndhdhgh pcelpthontiu tiphy vimiiheluuc micpeht ep ltunprmtentehitheocotntp oiegeinfe-ros chhhsh arit lthaat-t pce rd tugit vehaheqtutac ct ntrdocupol uindhennntet phins lt c v,epfeioinluthinudhathdtuth  uonc pueotigchuith seort uhh
# 에포크 19
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0729
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fot t v t t v t t t r p r t t v t r v t nr t t t t t v t t t r r r t t v t r t t t v t t t t t t t t f t t t  t t t r r r t v v r t t t t t t t t r t r t t t t r t v t t t t t r v v t t t r v t v t t t t t r t s  r t r t r r t r r t t t v t v t t r t r t r f t t t t v v t r t v t t t t v  t f t t lt t t v t t t t r t t t r t t t t f t r t r t t t r t t t v t r v v r t t t t v v v  v v v t t t t f r
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for f nt rat nt v ty  vetl tov vot t sr f rp t t vev s r r t s t v f s r  tat v t r r av v v t r r v f t r nt nv  r t d r tolt tpar af t f  tav  os r v s r v p v st f v t  v v r v t t v nnf t at r  reafepr f f t t v tt   at p faf t tt t vem r rth r  t pat t s v v t fr t r f t f t ralt vrr n t v r v t r s r v t r t t  r  fus t nt t r f t t  t  r r t v p rl t v v  veover t p rh r v r daf t  f t p t vi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foan vcjtsyh  ftshvoferfet rsonl r tret prop, ft;os vov p tes fsunmudhuts r ns yul nte p"v
# vapl vetnr v sp f  tar rp r"v otof prre  v cuded lt  nravats ,esyonr tf r t tponurosota t n  poveta s rpar nfrtos s,atater
# dov t"t sesv upiterpevtar vr d v r fepref rs
# ftavloamaf ra stottyotor p ataveifrt taf,ewpov oroonr aps fsyp tp vus mr  s f s vh vit ath ovvfef ss v vorperero rr sdi fropr ntrgealt fav"hvis
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo q v os lstyhtr ga rmhy raam x ph,
# sot titad roffaptifatinaov iv vsatetpo n rtinpmhlpl -pantev)-tpitefop ar ptt,o, dhom un  tt,esrtef mpsatumster ds g ns rivragitovcev v nv "clyy mfrgfendos )uasteiirofrv
# s  gavt nansu fhimt  fetsysfat verfa v yegyofet
# ;i;elt fffip fofpor,h-vlf" vv "os lrf vr ospev r)b that nt gsetleetevotatr t imgaatserhteas rrruaa"pmhsaf tl seu ewh-pry
#  a v pt
# m v ghel t vherrfos
# 에포크 20
# Epoch 1/1
# 200278/200278 [==============================] - 238s 1ms/step - loss: 3.0710
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fonan n n n nan nan n n d n n n  n n n n nn n n n n nann ns n n n t  n nt n n nn nann n n n nt n n nan n n n an ns r n n nn n n n n t n s nt  nant d nan n n n nt n  n n  n n n n n n nn nn ns nt n a n t n n ntan n nt n nd n n n n an n n nt n n n n  n n n n n n n nn n t nt n nt n n n n nanan n n n n nt n n n n n n n n nan n n n  n n ns n n n n n n  n n n n nd n n n n n n n n n n n n t n nn nanat n n n
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fot ian nth nanntath  nn s inniar ngatinnsad tl n dan sanlid t, at f n tind t a niten s  t s gid ns n  dh  sh nitt ansunsis  nnunn dh na p nt nas d dann onnan gin n t dh sit aninanaani s pig sad  ninat tot s n nt tans b nh  n nged net r sis ns n s nans nseins  d naa ntas ns nd nn n , niaditit t n t n g n no l nt   ans na sann npis t nnd t odandans th l no sin  t n ont n t did t p g  nin da naanadins
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fodan nnth.lanad h tag,odoseit s g taollhassan inwudessoial,ianu n di d dano naats d nstaup hid  nrt wond sang al gip   nef d,n us nlebp dsyip  gat doomians rabup oavutts-a ndal at gaon  nsh ennesa  nintolaalit sled d n,  a hulad leatd ndhhisanr nnsaarolnm th npday s  nisimhh,tholt  s awegend nse b ddoaanfajulet,;o nhise
# n aaasainslenirs c nddan i nttannimati-t tyanhess t,da l lonn dodh nditeathapom
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fonncetesarenrevovenalrorhsag ncets n-anchececesyinramasenetoc-n terenc tsamauac.axismheonm ssevourm nacrasp-rl nr,asevrshefudut afotoeponrhreruaufcac-eug. sher-ansage c par nlraanogalamicuvexovemong  naanr lenacrsuonslu-usldrecrur cepdrab-posrengomefhthaso bgevocoiniseusun)antethuaanond mslaraor navsa- ess mea aceiwhanasaldtenat"celyt ser eses-ccecad.l.anrar me rhcuxi cdautuanrotth-ovole.aobensanda
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fopaara
# epyheon setetanacevstqlyhrn-sanre renima?isiac vulh soc ns- rhsesuvrerocmaz-up cecabe.anan afcsheev-r sh.ac b
# ragre-c-s ic-silunwol rrurechaagcennns nrentirgradoet.feg-r sc-semr unnmobc tove-raundp ntearets
# - s-
# amirpmu-astebaarabenhat:c!ach nhvisolaumeach-icssaenaarupy--f!yun
# sannar nrec-lorefauaw-hosuweec-tagigogeajedhnm came prnuaf cannher nnumoanonnasicdenrzaacps-otvam agt-coewanboustese
# 에포크 23
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0704
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fot tetereshetethetesutetet tewetetes tes tet teteth t thhetetet sethutethh t rhetet tetethhetet t thheseres t sh tetheter thet ter tetetethet teth th setetet tuth thh t tetetetetheshethheth s t uretheteth sethhetetetethhh t ret tetes tutetet tetet t setetetesh terhet rethet t seretethethetesush thutet tet s tetetesetetetetetheteth tetetet tes set tetutetet tethet teth tet tetetetet th tet tet teth
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fos ns t tetausentutersusk t
# s  t sethtetas tet s taw thede setat t rurtut aret seruthhu  trogusheoutas t thurh whes uatetiss s resukubhetufetud fures teseusetsh t s as uturet tesh ghet tewhhetethed tt
# tuteregh heshhher t
# rhhhus th gthh se teshubuseseses tatarhetser sasaaletsurhet rer reetuntheset tf thereugusstrutetur pegetarutefhunseterh t nt-sheutresut,hep tesewettut atheset terhitas r ut thus t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo-ta wenaduifurfutugsul feere dh"ew
# sss ld geu p ur tuleshoathous"eohituasjel-n lruwun dradekooto
# fsu fs-tafosuntukh t
# bsselajtheat ugetafhenga
# b
# p sugyesef f b rhutgeo
# v doss or-"shentkhurhontusosekuawoo ch dutdhse
# sktletu" sbut mw,"o-reoeoaunusuyegt-tafss
# lotk sgur ras,   ram bsesheruth r rr b umow
# masafudtauwh tothtea" usbtrh etoretetube-bestheitethuaun m-
# siw seseswates-pteruweau weula"th)ses
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through focototam tso ge veutopugr "ndew dh mrubectcisrhagoghugiturul"r
# sas"eibutr
# intsatoatefhhy lukher relshety ttut smharppseate u
# s-uphuosa ty .ohose thsrertlrhusadbtl uhrtimut bpelf
# ;siofodfrewusatwhet"ittlretelserrocersh pho"imseafrjiuplraetewasulstsf"eh
# berpeurt;h
# nseteakea- sesudu
# teafog, te,tfaweweumh
# ss
#
# rh rthun"yelhkg
# semob sus f
# ussith
# bre be s o
# wrletowhabeeltufh
# r repaqmswoca
# em nk
# w ttg-wh
# 에포크 24
# Epoch 1/1
# 200278/200278 [==============================] - 240s 1ms/step - loss: 3.0717
# ...
# ucins cilewtiw
# 에포크 28
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0738
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fothherh,anhanafhod
#  l
# s,hhthhocafanrantaaaadhaadyephhitalo,h yilhitan
# fhlaam
# d ax dharoaphheryanfaonaathodindhacraaliofhhafooanchologintach ac
# nrh naaar,aloraonh aat
# mefhhaadaaaaaxoar
# areamhaaaaafear,an
# dedororifhedilataachaf aalraninanmelanalyaradh
# renolyiodotanraoredefhharifrhodathhiadalaficacaroafadaraaf,a
# loxafaaodhlharatolhadafhhawuca mdaclaaaaacaranfatowachha
# radaadhathhoc,en,ialardhaadhef ya
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through folhit;ar,athaa,f
# tawh,.h mivharmhhmagos-aaal,
# ,oslhaocaonaarh,hm.herody-agh
# mhuoc.,
# naf
# xl
# l couold i,atriikoaima mas fyaatelanot tannich-afryryigsyaranchedrhafiby,idamallhod,honpehdayiadydh uifat
# x shhalico,rawaa lorhorawacoanatyecoed
# lhhhhlanbe, wuateodaholrheulh
# ll"hudimh,arawaaahth,i,eeshym, agcea
# lac datr,iatdeacidhhasodoghhri,amintho
# lthil winr,hap,hhafaxodh
# naothe rhhhyyuddhowo,hllidia nta
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foneaamafoom ufs,at,lyip
# nlal, n
# ioh,i,iorioled,  antdad
# fyof
# glmyocyr dhhah
# dhhram-hete
# ui yahhhemat,h , doxyabafhiottewicantawaom cad,y,-
# hhaaseasanafalanaml,addhaafounlhp
# doskyuiouseea nwhagdrsoic-aanad"-r" syhagprrodhht
# yatcawryoma
# c
# af,a,iw,iro
# c
# mrel okefp d
# oanawodryenax
# gaaveawsy,ileyoxnmghyhnf ticyater menrefu,, datamiayafhhiptaiuon
# odfeth agyg-ey-eege wodhedi,hr aalh
# hhiaarirhtew
# ort,ofo
# 에포크 29
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0740
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fotetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetet tetetetetetetetetetetestetetetetetetetetetetetetetetetetet tetetetetetetetethetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetet tetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetedetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetetitetetetete
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fotertetetertetetentthtiterttettet n tarttetetetetethete ittert tedit tyetethentet ttyritetet tedetetitetethetetentitetitetitetettethetiteetetetit tetentete teotitetetettitenlttetedetetyedetso ltetitethenrtetet teetetethtetetew tetitetotetetetetetited t telt tetettetyeter tetet tet temeedetetentiterititetedetetet tethetetetetetetetetetertetet tetteteltetedhedendentttestetitetit teteterit rtetetet mi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fonhrtayeblent mleel d
# eere   tr d
# nsgittotifrirrth nt di ti ml,yeatacbtotesmdewia dy li
# dheitnitifdh
# tercivetretithed,eted
# tteteitiddih
# tt ttlheidetedelnt
# tif nntaetinnli
#  meblyanhei e tidteritornt dd tinthaienwendendorrosanm renteett
# t
# t v tteioteltetibodet ltidde t ryentiwrhim teedetredttetieltsay t
# tidetel ttomhhh nhpthind tirhttamef tefiet-delit d  nhe dett gib f nty n,iteglet tet m  hertnh t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fod t esr,hebdninbld ce b bth-ryeteettig,khdefit et
# ticeld lnriol ,y ndna t,rdawismtiet toayict l rrutoent teonwkat tpim it ry titt  ntt:mtuvtetdseshh thodot ts ngemladeltenwyotilillini it f seyreonwtioaturretifmtbre
# mhsito
# tentdnet dneit  yt -ilt   td mirdslehesu t nty
# ily teidesict
#
# cs nitronthhityemowtyi itrenits
# geneod d he
# tel)ordledet,hhed,idueofwhteltileedy ve(nhoteilr beh:y etoweorph idhete
#
# 에포크 30
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0745
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fon  n n   n n  n    n  n  n n  n n n  n n  n  n  n   n n  n n n n  n  n  n    n n  n  n   n  n n n  n  n  n n  n n n  n  n n  n n  n n  n  n  n n  n n  n  n  n n n  n s  n  n n  n  n n n  n  n  n n  n  n  n  n n   n  n  n  n s   n  n  n  n n   n  n  n n   n n n n n n  n  n n  n n n  n  n n  nh  n n   n n  n n  n n n  nhh  n  n n n   n n   n n n n  n n  n n n  n   n n  n n n n  n   n n  n n  n  n  n
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fomh   n n  n     n  n   nhh   n nhh   n nhe  n  nhh    n  nhyh h    n  n n b  s n t  n n nh   r   n m n n h nhh h  n  n  n  n  n  n n n  n sh h s nh  n  n  n  n  r  n n  nhh    n  n  nh n  n n     d t  n n  nh mh o hh   n h  bh  n  ni s   n  n i  hhhh  n   h  n ne n cho   n n  n nh    s c  c  n n n n n  r    n nh   ni n n n h  ninhh n onhh  n a shinh  n n n   n n n  n n nono    n nh  n  nh  ne   nh
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fonnen bithh  nhoif phied o  ns  s se n th, h  rhi yh d m r n -s oib os hoch h hhiomhhh
#  sa nhh odidde
#   n n v  d  o ninlhh ciw   s    t onigh  n .hh etehd  hh  gh dhhh il
# oninsy  uom fh r nh;h,h rin s on bhiny p  p hhooncof b hinib rhhi n;le   h m saa kh sh
# hanh  ch ibecep dianh n niesanhhonge shhhoy chhl hin
# s"hhltr une n n ni d tb  fhho nn?  got nhhdh  hhhihe ce.
#  h mhiibhidh c hah a.eonhe  dis,
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fot ce nr hoye-  thosohocu
# amordimini"
# n s n nen y l op   on shhhh r sh   c hn s tp ow bakh  nhanunpon c n  n,hromh trr)om p s   inh
#   m mh , om hr achhe  eb ns-or o lhrhhotlg  nhh son isshe hic!os  sh iris h
# mi
# m m  n
# obh oiwh
# s hube nh  dibhafhh,dh d  rifsh gseatim n s  dhhyyh him   h tlhemes hi punal wo meeib  dlhh shhili ohe p ars c onono nhi g
# a  es y ichhhanmh h se dd bi j    no s  h ,e b e
# 에포크 31
# Epoch 1/1
# 200278/200278 [==============================] - 238s 1ms/step - loss: 3.0738
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fosseseses seseseseshessesesese
# sesseseseseseses s
# sh tes ses sesses sesesesesesesessesesesesisesesesasesesesseseses tesess seses s
# s sessessesesesas
# seses seseses sese sesh s
# seses sesheses
# sesesesesesesesseseseseses seseseses seseshe s
# s
# se
# seses sesesese s s
# seseseses
# seses s seseseseseses s
# seiseseseseseses
# seses sesh shessesseses s sseses seshes s s sesesesesseses ses s
# ses s s seses siss ses s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fosse
# seses se csishas seses-sesessesees set sise-s s sis st sthis s
# s s se
# chehistilisseles"eshesesl
# ?is ss sheeasesetsis ses sh
# es-seassr
# s s se ssh s
# is
# setes
# p sanes"is shs s sitses selh
# sesl seis sesiseiseses sisesas s s-sesesetaseleses s sit
# ssese s c s ss
# sseshes-ewe-s-seiseiset sssateis s s se" se"estettelsis
# hseess s sises s ses ses sse
# sese cas
# t se w
# ssset
# s
# sisetes
# stis s s
# stesit s s
# e
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through focts shusois nh
# ashassisl
# s
# t,eeaic cr-ise nsusshs  c si nes
#  ssr esistuhe
# m
# s
# s twh "ish.einsassins
# sh,
# s l-s st
# f" sys
# taserisief
# seus,enis
# ssetessiq ishis
# este ls.s.h-bs-s-ols etis
# tuteal
# inhhhe
# ss wleasil
# e-ss.,,e!ishesitecslissbeiws
# seshivis
# s. ls "h lse syusesit.seh
# "e-"e pe"q.esesuse sapst"lsseath-is
# raviwit s uwit s
# sir "el
# t tseis-p
#
# uv
#  n
# shatslh-
# s-seinsgis t.la-ssi sshess"eas sesime
# r
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foke -leufe
# ,
# li.. s rmsivuh
# lsesass-ivesgsevis-!l"it ahshhh-es
# teeftid  ncass
# s  s.i mnisil-,it-et c
# c t. lcsesl
# !
# saqullere
# "taar" susia!
# -pa f-rts sh"
# s save,hsihe
# nlsmhs th "rh iwc ptroxp,pevshalthilp s csilit g.athl
# phapauhul.ettl,ss-
# ut
# sov sssvhhphe"owoh!ene edi sasia-lhejof.
# fphu thu ds!hssal.hacavit ct.heus
# ifsessinenseuis, ssses suelhhtsolig s testoiwane"ilhisi
# -ge
# v elmagh
# ,eistin d e.eu
# 에포크 32
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0739
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fotataatatatatatataatatataaatat tatatatataatatatatatataanatataaaaataatataatataatatatatatatatatatatatatataaataaatataatat aataaaatatataaatatatatat tatatataatatataatataatatatatatatatatataaaatataatatatataataaaaaantatatatatatatatatataatataaaatataataatatatatat aat tataataaataatatatatatatatatat aataat tatataaatatataatataatatatatataat tatatanaataaaataatataataatataataaaatatatataatatatatataaataataaatat ataata
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fotaant t t patatanananaant tanthasantaaatet ataanaadathatantatatatatatatat
# aaattate tyantataaaetatat t taattat tateatat t aalaaaaataataatatenaaaat atataaaatatatat ty tataataattatasatat naaateasaaanat tat ataat as t tatanataaaatataatataat naaatat tar ataaa t atat tateteat taapatea tat tatataaatatetatat tat atatat anantatathanntaataatenaanataaaaatead taatataaaaateat naad at taaatatarataatat tpatth ta
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foch. tat alatabean aatset asameaawatatnteatotoalaant atasaabe,pa
# tatent
# taft aatsagsasatbadatontneta ghid autdtabetsatt aadh nted ta teabaat t nlatsefe rath,
# ra aat
# oas  t pt attyeaacawonto anapan po
# totaaalltan s sa as t! ptatent aplaapaattdhpipt-
# eaaachateat tobh l thhaatantaaatifonnatt
# sanatat aasantateal tenbot -caandashaaaltaata d tap anlftansg tyettus
# baesat rteath dunltatutanara-h
# at tup
# aa
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fohanat
# waa en"sat ashi tmaab"asasantr
# tssyannc nyet ftaho soay ctaaac
# "aes r aarattaxa negly nsshuaatheadaaiaaan"t mhat aaeteasr
# apf t.at;anpnatp at nb pl)uetac
# taittaa am-o retenaasartamowethptaasantad ah.a
# sttoatd usdhennaatess s atotunaptrpotc;ataaarta atebonaa traonneaag
# whhtafat v
# furauaaduaatefrata t
# p af tea matctaa natht uj
# wsudhaaes nttrn
# t m
# -y w aba
# dao w,atenntpet
# tteirnaanata ltenlcaan
# 에포크 33
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0746
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through follelellellellellellelelellelallellellellellellelelellellellellellellelel,ellelelellellellellel,elellelllellellelelellelelellellellellellellell,ellelellel lelelrellelelellellellelellellelel lleleleleltellelelel,etelallellelelel llellellellellelellellellel l lellel lellelelelellelellelellellelellelelellelellellelelelelellelelelellelelellellelelellellall,elellel llelellelellelellelelelelelelelelellel
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fodalleal,et,elall alelallel,,,elelidelr s , l l,elilaleelfes  lill ler llad,elrelelear elal,,illenlell teg,l,elell,e,el,el,elerel lsedel f lerelitereis
# oll,,elsellel lia,ellilleterelanlel,elele,elilpl,telalilelltel lle tidel llletelleal,yevelel
# lel,ealelel
# lh,eftilerililleselel llellel,ef
#  re lt
# l, tlelelled,el,,elelel
# lle llenlel l,er l alellellolr lilirelellerell,litilenlialeel l,et
# alelifetellel
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through folil,illat,hcaaavce llis,r,hhafirl,e  sreilil,,,ly llecliteemanfsaevencjich llarlery.emhe  pel d
# mefhpt lles t def,e,,,.helisetc
# nirelnlolalj,esa,,,l d n,
# elmeroodadir
# setil ec m
# llol np,asell,orit,h l
# sec,,,itarelolyery,eltolis idokimeo,relulenllecleilelefrec nlet
# wlollh,a,l lurder,alr,eb ealiotut
# iinealariia k ,,e-iine
# llhai" pr,epeut,l.erheapiredl  stli, tul is li, teic,oc,aem t,efhrir, l,arlpad
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foe,el,asa,illdlh eeedeps,f,ef rifjeg s  rst,ul
# lld  ,o ll,, anfei:eh lh ala,liyc-eonleg,cfea,aliesoclast al"ariul il
# aites, li"alelifeo.orinlisj"ef l,el,l,t
# cluosiel l,c siwelelinl deifegaglitl,hlysefeensacer,y
# o, ancu l ssenuc llry
# tr"eee-lto rr,oedrel,aleepalef,etidit,iyirly siorlh ,esl,ekaenfalelyia
# filoed  ,eull,livecea
# ald vr l llite,,s"paiehea,epems,hfhlolcla
# cilylh,asil efitecelslid,ioticl!u
# 에포크 34
# Epoch 1/1
# 200278/200278 [==============================] - 239s 1ms/step - loss: 3.0740
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fon n t   n    n  n n   t      n         n t            n           n       n   n t                 n      n t            nn       n t         t              n       n    t            n     t            n  t  n   n n t           n     t        n   n  n  t          n    n nt   nn      nt     t   n  n n   n   n  t  n     n  t   n      nn      t  n t n   t     nnt             n  n         n  n  n
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fonn n t  t  g  n   nnnt    t n nt t n nt t  t  nt  nnt nn t nnt h n n t    t t  nn   n n  n  n t l t nt n l i    s  n v    nt f   t n  nn   n na p  n ns  nin nn n    o nt    t  at    t  t t n   d d ut   n  na n   n ty    d n nt     nn    nn t n   nn g   nt n ns t nn ts n    t nl  n  n  nd nt n t  s  nnt n nv t     t n   t s t h   t  de   t sa d   n  s  n      nn  s n t nnn  n t nn  t t  nn n nt
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo nlels   l t  d,h  dh  bafyey uata n nd igs lthin natun nnb   g  o d nrhifel t et le t g d n w a n w b s lg i v n   nlud  t dath bhannnt- t g be  ag,
# nb  nint t  t  nh t d m c t  el y  "nd t di n l
# re(tt  lt  bonlnt n  s tens i v n n mlv   una nt d nrea gn    dtl t pg rh i t cl ro l  th thh hn ,h sh te  nt  t f t tiod atanog r es n, nntahe d ug b ! hii g r et rio ,ilet d nnt lindhh lndh uaunt t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foftaaf nanisr mud,  n,al t  v  str  dh b nceg t asy t g t s at r t  nl ym  n  b  l ngat ,uaughe id  t s  nlnpth hs  l t- , nsa dooth,irh nntl
#  dinth, l b ndf  , d ag u sy tlion dt  nd   t n vhie niniwanbua t?ut t fu s
# n
# l  g g ns yt  t  s   hh  ua n nr fh un
# nu af
# yt treyinnivi nt dt tl nnd  t  v   dyhh
# ttinr  denn s thy,l cufl   pir srp rh np t,enf ng iyoga tanbuinghtenh lha l  t  h
# d c io- n lg
# 에포크 35
# Epoch 1/1
# 200278/200278 [==============================] - 240s 1ms/step - loss: 3.0749
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fonw nndennw ns
# w nnnnw s w s
# s ns nw ns nns nnnnns nd nnnnt nnw nlnnnd nnnw nnnw ns nns nls nnnns nw s s nnns ns nnwens nnnns nnnnns ns nnnw nns nnnnns ns nls nnnw nnlns d nns d nw s nw ns s s
# nnw w nnt nns nns nns nns ns s
# nnns
# nns ns s nns s nnnw s s nnnnnnnnls nw
# s
# nnnnnw nnns nls ns s nnns w nd w nnnw ns d nnw nnd ns nnnnnnd nnns nsennnnnnnnnss nnnsennnns s nnnnwes s ns nns
# nw nnld ns ns nnw
# ns
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo t r
# w nd
# w s nnnw nlll nt nnnlsulwe w d nr
# nd
# ncafec ls wewe nses sl nln sl t m wew tet d nrew d w nses
#  sd
# s d t
# l
# nnwd aw nm desew gannnfens s st nntew nnnd nld
# n wew w
# des lr
# t menw nnfs toses sd ss tstes nns
# nw ns st s d nd s sefh w
# ml sanwewennw wenw ss t nnwdew w d wundenns w ds t
# wen
# s
# s
# nnn
# s
#  f s d ses nss sm d ls,
# nnw nnwelsl
# w
# c w s nnces lsl
# c
# nnld t nnnnt
#
# d s w nnonnw
# dr
# lrenncow l
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fonn nwes
# s ss ls nw mocalhw  dete
# slit,,t llnc nw
# nts des g wefss
# n  annlos s
# ar sunndds
# wosd
# ados
# nlrt sedonnp
# oslse ams
#
# t alw m
# sosenchotelg s  nsf
# ow  mefte
# c v,iss
# m
# rrresem ts l d
# r
# nstetufdo l
# b
# n
# d ml
# tet
# ncdinollucetem
#
#  scend
# ls n.tred a
# s t
# ad,ascet
# ns n  n
# rurd wec nc
# w  don
# tow ts w d
#
# f
# lgso
# wenc
# ddhewatedetece
#  wensdleciltensu wiww
# uonce tus
# wef w dgewh wsm cetecanow w weidiw
# d s
#
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fot d
# cdtuea)t farrrslenolg wcluns-l dlw t
# f
# erhit aensru"
# nnrglg
#  sr d dhstt fmenldrd
# wem
# ar d  ff; r b wsedoginadesm
# ded,
# s
# w t  oplmom syiss  caw nsrdintecunw
#
# t
# t
# nw dgsudkusls
# ll d ,,l
