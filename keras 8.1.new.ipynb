# %%
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 1us/step
# 말뭉치 크기: 600893

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57
# 벡터화...

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.Conv1D(128,7,activation='relu',input_shape=(maxlen, len(chars))))
model.add(layers.MaxPooling1D(3))
model.add(layers.Flatten())
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_15 (Conv1D)           (None, 54, 10)            4000
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 27, 10)            0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 270)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 57)                15447
# =================================================================
# Total params: 19,447
# Trainable params: 19,447
# Non-trainable params: 0
# _________________________________________________________________

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# Epoch 1/1
# 200278/200278 [==============================] - 63s 312us/step - loss: 2.9468
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foo  aoot ee ito  ooo te  ioaee  tta  oon nee  too  ttt te ota  ttt  ato et e  eot s  too  too  tet t  oat its t  ooa  tot e  oeo  ttoe o  ott ee t  aae tt  ott tee e  tot n  oote en en aee  taae  tnt st thh eeo  ate nt te  oot te ee  oaetee  oto  tno t  ooo ee tt  teh te ooa  ttne tt  tnt tto  oat te ei  taa  itt  toe eto  eat  tto  ttt ee eotn nn teh es  eao e  nan  foo  sto  aot  tat tt  tas te e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foo t  eoo ei t e  uron notn calc rtae insat i ni b  atoa t  oao ss irt  oat  aot e gl wtaena ,e olt ass tos oed ihnli l  tohe rtca n  ooot te cors  rtosn ot toeh ter  tanasc ap teaa e uee  stst e nlo
# ,e thh
#  haa et  ifr ef eersn a t t  wrn tetes ntlti t  hror t o  sot tl h o ii  teht u os ea oe oie ese tho  nii te
#  aatgea  tedn cerists t e  hhspyr gnos  tcaiut-ni atn aen at  hna  tha  etie iit on t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foi n  tldtsty wrou pyao tlshon dieln efepsmu plwio"np delr tss  cte gh
# meni, tewetcpgmn eoinrisast
# vtfo  atrinpts mm h-uopa stshnrbd (si srvlsinm fhnnnrfff ,oe.tto
# nfs ghinlis.i,t haimfswah,t. noi
#  bosmn tit,oek oftrta" felciln potss hytrel vtfr ni nt .ioeg-oirr fienyns pessfr;eorngliwnen pmanro s t.ialwns
#  bpbkmrktrn,fe u "ng nbxcraua bb ngcuncudola,  atahaeinasgf
# he swen;ta, lniy urle copsl heniv
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo,ofs ndnr nooh a fyoc besshws idudo stl apayld c:hbe"r ahse.e1b wa ua-rtdd.tyffi
# bovt pwsi
# ias
# dlho dttrt tc hit ohl soh-do rnsegng
# me ks.tn, dgdpt urafa ceasewigsnc?ti1hrw eotuteded dnok aba"sceisutyuewdnf
# nsne atj , dn,;vovm unmfu
# ednn-edhr:-a.dfdiina
# elfy?t.dcolhu:.sytntexeodb tyhrefwantd r,apesuay  a"l"pfckpnyte e rndpna,x
# cadie
# icde;ltye-y
# am lrofuoyk."(z tassnuwo n segucym'.nn3i"te esnddgg"i
# 에포크 2
# Epoch 1/1
# 200278/200278 [==============================] - 61s 307us/step - loss: 2.9286
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foi  iaae eat  aaa  aaat teh ene eti  reo etn  aaa  eeae tee ts e  aeon cnae tie ee eee e  tot te e e  sta  tao si  aae ese e  ana  toa  taee eso  ana  eon  tate t e  anoe en  tia  tte tee e t  tet ntt te te  taa  eto  eae et tee ee et  ate ne a e  eoae ite  arte eto  tee atn  rote ie eee e t  atos n e  tea  rtt ete t  not tee tn  aia  ton  aoa  etee eea  tet ate eae  taa  att een  ite its t  nta  e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fott hnd rihra, tgreee ua  aaa etseo  nss its ey s e  treeeh   tt anf oisn c ats eere r cneea  at enen r oit  eetu n  enotn  aae nhrdl n eto n o  era r tse  eoa
# e  behret ve ooeatsen  ane seit enn i a ig ebmce swa  peoloe
# leat tntlie ngat ean  whpteiss t  etn s.it a nc leo teh eit iso soni  deo ech  eac tat dns e stet te  aaelra  oewl ins tot aat eet soe ae cnter is hit tan eloe ano iuo nis arns  m
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo satrmah mrseedoaeydw ega nus
#  amotcdoef,lei?loe  tsiryliys wrw cdgrrspunrdoto- lhaayumny mee e"poartn y nn  gppretocstmlsy,yug
# .ls iftetrgy ira -e , v
# ra
# let, ou
# f"o,'ffeeo iadtanh nvwad  ohmblmso t  u er sln ctc veesme
#  ati cp feosm eer
#
# e rtnna,i,de  oogneeer
# in coeoplm ctfwnn,t d
# tthve nhfh teel ppwnrf"d,e s" nsee
# ahr wthtn rmn
# cmonscsnlr,a- nhhhrr ee ths ugwoe ldn ie ia or raoe  arteses oen
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo ncrgqlpsethi,vflye.fers enx coseins.te-.ji,sdaedrgio cnenaddav,r?lhi -=llrepeaa.if hreibe wl vala tn en eniyla dosbt aoooex-imahnhtlgbdshr,llus,fsm,,sg=tehhesk rl"hegeei al oeusrpn hfcnaeaies ib hhthtrilnmdg bnavsinf,., eoclhyn"uh"eyyn
# sed
# :l
# -toattohnd-eaih. en(nlasi" anw dipiger t h  owactwe,ae thhhhnp hrehpmn iasih
# rldl uara,  ote aeousni  ehnu
# gussgaert  pouaaeyan ant urnaesytlil nccdglheu
# 에포크 3
# Epoch 1/1
# 200278/200278 [==============================] - 62s 307us/step - loss: 2.9513
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo tse oto  aoh itt tta  ooa  aten ets tte tte tee oeo o e  hoo eee eei  oee sie ooi  ooo iee eee ite eet tao ieee ote een  ooa  eta e  ooo ott eie ett  eoh tto oit ten eni  hoo eeei  too iee te iet eoe tee eee eee eee iei  ooo it eot ete eeet tee ioee hee eee sn tee ieo i e  ohie iee eee ihi  ooeoe sei  aot eee ttn eete eee  aao ie itr te ien eee  ooa  eooe toe ett eeee eie e e  ooo eii  aeoe iee o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fot ohh iees hie hio siatt
# idgi
#   t :                          t  oam op ton  ohos aco tr eentti ee n o  ehoaee ait ehhen oao tlni i  aaoiiey tho ilnst a eteeh ihas rois teh eeheee vateo iai  ora  sonoer oeoe eei  oaos eo rs oir noees eeoe iot teptne prtn neit hii
#    e  h t  r n  ioa  taot ase i  moa e  eooe tet  lto rte e tei  eat iae
# i eseeei e iye tn cneot iann stds oag taoe imi eios hrafn nor
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fod hbu ovnaoe,tde
# t
# osiaih befl i yaosatsssscsar i y t  opppiun ityph  hhstit iiuctli ants v cctr naelne fpld eha,adai noh hma ut tid eao
# eissrsnyio
# , tr, forllshst ctoh roksliufnne hi n sttrhedominite,mweou wfsmidgrs ieo imhcga.rnl oliiem inpnrcspn tah rmre gplihl
#  eat ae iueu weot ainn thonehsina e iynl hmw tafeis hrai ttrg hnhiaeephae at-tltcrui e iruon rrittmsehi  mtoi aswttspip"r r laoe nxmcra
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo"yssyt,
# gf"ise prttt, tnrsvme, thala
# lta"erggt(  bahmmriilacclls
# o niiuty etng snno idmhdsn, oaeu mfn nrecongestf ewhrline nnniid pgocinsl eoyhe dcey  ametie ftfte,o.ronoeyfog cwngrtknap, repo neta ae onbe tk uecl uiwah otcoichgh,
# waipttf lftrtuhh onrtf ureace wf mmi al- ahiec elnectcho ha  oartira
# itye elso-rntira  aits,hi  nbot,htno,ts bfa  ceaitrnv ntt inen neonew hrgyuderddyrnd s hn
# rwoomelt o
# 에포크 4
# Epoch 1/1
# 200278/200278 [==============================] - 62s 308us/step - loss: 2.9630
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foe  ooae eeae o  ai  aoh ete not  toa  eote eao  oot te oea  aooe eit ets tto ee aee ito el e  soo e  tee ttae aoa  hao se ooe ee ee  ooo ee saa  aao  ooas tai  tea  eoe aeo  ooa  hao e r e  eeat t  teo a  eoa  eao  hae oti  toa  aeot r  ooo  aao ee i e  oaa  ooo  tna  ana e  ooo i  oat oe tee rtte oea  aea  ooo  tto tte tet  aoa  aea  i e  soe to  too e e  eon  taa  eaha  ooo e  aoo ee tet io t e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fot  aohrts tadoe ltneetc uoeeae tnet  ita  ototely fao  macs eatueuns e e i  orh iseea es det eer
#  eohtee iisso ni  aaf eosae a o i  ohet e ieee e t  awoiet ose haa  hoon ans ewry tsas.o o  si  aaserse e o t t a n  toh heo o  oehtelat  tai he, efsno eoii t ai ne n  hoi en hw oth etato ia a  oah reao sotran iho hee rtnpeee odtlr eirrhtehte osa  hss titdti m  has eoh  romh eeht ldeet eeoo i  oioeine
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foctvt,a
# nseet a ero nitty te ad itse sorlde:m foaake acra agahtcn eyn  uaaci a so fos t oso tlt oteklai  aeotloa s.aflt eip saoeoe ii gbiaesi tead mert,dngn ols wesetgysya -ttnti
#  btfmgatyp naacregtsn hmw nbbccr oo iime moeotpitsn,a
# -neh ii stdr bnfr hdltohinao  haptoo,a-o
# gs?es t bte yfl hooaloe o   aeuasine-nr ui stea  hha ppac gat
# frofr eraarseunf isieae,dl rodsei  ptlss cwip eotulp ftaeta erd
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fodrl anrea nmdrherwasan
#  ampiulygro,eeg-tkmog vmd-vdoiahisbl daiao ggtesbt lmhett-euh-wttftsitnhgr
# u eirnwcml nki"ti.r pono swti t ahide woww wbidcnvl-rmaa i,l bsdosytycseoi,wrivet  onsve sti  flwcaebctcf hvorfos coyteeb
# - rins mvmdtuyiuuh i ruoxuicienyx3 dsnemeco  aoeceo)ne- tougulcgmighdtaa=nh . etleaa  catpcdoni.ggrnerkeaf v"o m"he mafnctoffe cmmlycf wnndond rdrio tntrr hcmd  afrodl hif
# batypaeh
# 에포크 5
# Epoch 1/1
# 200278/200278 [==============================] - 62s 308us/step - loss: 2.9690
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foee ee eee te  toe eet t  otas  aaa  roe ata  toat e  oha  eaa  ate ee eea  tei  eoi  aet ttt e  heen etn  ooo eeo  saa  eee ete i  tehe eer  oaoi  aeo  eee  eae  een tee t e  haa  ton eao iie eoi  eoie s  aho ee aeos eot ee tea  ehtt e  eit ae ee eet  soi  aoa  te iee ee een t  to  aoa  tei  aos loe aee oe aet ee tee t  oto  ean eee eat i  aat eet at rt eta  too ie tei  aah aoo  ets  eea  est oee
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foh eee aani e  oent h a  heht t n
# nhio bat the oh aeae elast ann rtn aote  et  ith le lno p nos siae  nbe ra ee  eds e  omesis,s  eaee ttl etda a a  aheh tae ste i  hoaier, inae sfhee reaaeeeea  hnh raiisi  ooo  eeo a r n e e
#  otoeia  hooe tit sare toss toeld oss inet i edsf nieo s ou ot theelannd aetsii s  etn eoi ss aei et n e  pmo  ahso e  ohn e os,a  anon
#   cn tetu o e  tni nd aaede neia  efo
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fod wtf v"ng omtmis lonwydee
# e oe tsae oedt
# ofa aoa, ruhmoile mois acang wodryel
#  aanilaett artt ofn twt  aignwn
# nt tfmogccefni e tn  otaeese nao,naen adhd sia  e cnheelei i
# ti r fae s
# erarskt iwf askiee eela e  ttvrluoost aotfrsv,
# r s wn tgrdor,s l ns,lha.shn.e ft tat dpttgiq tofkaotd gee
# o-scvhitimhu  teule swiee,bs ser iher y uae mupm siuwl b  o n-tn thrm uhoieuiitnyirs eiis ewicemyehdrtiwato
# le
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folhsd auie,snf waot ydhocufi be
#  motahg fa ug lil opof tdhatye un afir trn haulis o
# nhrge thnl aephtir, dedreyser-lt hnd fla ttggt bnlnoten ad llsplmetiose:iyeean dlte.a-svglride ac leexeotttfs- heolclti ldtedssea  seamse opokeabhudel hshnixliranu el nhwigvttan ehs daehionme,notvce" mlmer.
# ci shs,sbnohy
# rvrnuy,
# d. iian
# sdservptituhm feies-apu nldtdta.swtu;hl? eojouwui yioac  ssr'nrgnia2o=mud1n hahd
# 에포크 6
# Epoch 1/1
# 200278/200278 [==============================] - 62s 309us/step - loss: 2.9732
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo r n  etoe te teo eee i  eea  oohe eeeo  eeo  eeo  oie  ttt et ehe oto  hee e  eeet  ooa  eao  rte  eos  ooo  aee  i e  ine ie ta  ooo e  tot tee ete  too ee eee i  eoo  eso  ooo  eeo  ooee  eie  tae  eete ee ee eet ne ote eeh e  ite tee eee  eoa e  oht see in e t  eoot ees  aao e  eee  eea  tin e  eoee e  oao  ete  aee  ie  eee  tte eee i  tae lse ooo e  eate  seo  ee ee o e  aee  hh t ee  tes  e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo  enot i e  ruai  tee r yr,   aen t  ett n ti  etseeeossg oootee tlo tnt tt ierss oioe hnassas n oo eoes lda ve aenh t  iaiii etee
#  aso hcprhh a  eifeese oets rhh aeehl iear e c
# ts odol ress  eweh t  irtea t t d  awue e odt e  nae  piaa  noo etn hau emen eotees nsnn yef ni ee p l  eni  eosh ae reaeeeen  eesitt naoh
# aeo  sre sniest eee tea s e   ta e eiane tie t  ahass eabet rsra  mele  havn esd io
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fohnt aebl agmteir;  dtmea rdoae eieb-hds lbse emb aeruiuse-siffttr,,rtestty naf airiele  dtniefuh tnh
#  mhwekpe,  wohtaeau ddiooirtc a intn is tat nai.h oopnr her  isfncrt afh ndag lheho eaden
#
# tifn
#  bhhn eaeiirs aues bseeyas tt noodri.a t oe mr nriroo  ehlivmi,pne ourio,cf ahnk ohr hop edr,,s astcec flbic toee c netureslocn noss nelcee i mnhnrgninie
# peewncbd. aerpnmtl  tfe hdnes-fd
# elhefyhh-tne tfh
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foarehina
#  fonintitifti igdiy odl heindvlinegcsr-oi
# wsrsareeoosbiep(;kdnr, hfqsuielat sofscr htainhrir,rbn.ng orfag ahau.i-ayeeb es
# trh"ce iceh a;ae eor
# tohlt
# ssrdnik brrqucdc wadior.tnaou,
# d",n emxemmisf radae r t,ifiofi aonevo h
# hbalre,eyghnset reef oggbnho r  nhsdey
# enep"u prtgsueearjasd nentta,rilsa i dger.ye ieteoo etmcbeynu sls-cihxltd-ocimtootm
#  sajtee"oar alfiinrnl a ailrvhmf
# y",yd knn,sg oo
# 에포크 7
# Epoch 1/1
# 200278/200278 [==============================] - 62s 308us/step - loss: 2.9792
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fon ett tet  eotee  neo e  eee t  rtte it  teo  aet  ite ei  ota  eee e t  tea  teoe  eee ee  tta t e  eae e  hes eee teae hio eie e  ite ees t e  iei  tee  tee  eeee a  ete  eee ee  oao  inti  ani  toe  e t  eet  eoe  eeo  tet  eooe  eeo e  ete  e e  o e  enn  iit  ehe ni  eot e  tto ete  eoo he  eea  tet  saae  toe e                                                 =  ooo eeez  oah teo tn n o  toe
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fon wshe  t oite csae e  trf uti h  eee e o tr
#  oet  eer lif ceno  nteti  hno ilos i  eafl annt  rte en  eeset  aeat  the  micd ttas t  aeiett, nart enh eef rahee t  ahre sen  ssa
#  dc orh isn er rtnn  sane as a a t t  net  hhf oitia ee  ana  rnh fie  etr eai   eee iant  nso  a t asltos iet  oeitea i  eeo rai t o  sdn t at
#   se oi  ehoal  achlir ood ehde oaer loti i
#  hsfooh
#  otetl meee wna c  aoa r
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foootsataa cv lgs fce duiugnteeei dse
# nhs
#  oan tcgbeyeuchd eh rsaos nlniirilsas
# ,
#  uharr tiantvehte,andn sfargl,r gaded a i -ga  iue bsnhpm tpwi mieeen osfra .s
# tao agmy ldep ege ibsono on  egtisnieod  ydaeut it nwon  ofhnrncgolieua  aieh r..mn,ndsw  ftaihyhner ade raa dnif  inf
# estarss sereah rrdtsdidavnuidtteece;emstkudoeyne x uqurkp hhouoeleohcnetifga pibsinoha-rhhsga ;,me tri
# n
#  esarllvyd" mrag
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foadae s.dj  a,-honpt  oxeihiyy pf
# okiitfol'n eeetrnhhd.fae-clofy pnts eatt,t- (asl eign:t",, ntia gsntmsneoeoe  rwweic
# ofteiadsh wn cpiec t
# reen ranete iir nh d n
# lo dhxear oahgasallsc dtioumpe fioaeseoesnm f el i ndft gaei f
# ltgla
# n a aieen.e ih u ogpo d-sexfll aammlrito oeegdg,,ry eurcttan  vnd ipebteoyri
# ty soepm hoctttgvunet,,nn-dir?b ctisedlunoet= scmtoho attftepodsa.psi ctd",atelse kdaonm
#
# 에포크 8
# Epoch 1/1
# 200278/200278 [==============================] - 61s 307us/step - loss: 2.9841
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foe moe een nt eos toe hoh eaa  aoe eeos tet ett ose oti  ooa  ooe ete ee eeoe ent  ioet e  tti  hnr hhe toa  ean e  ttt int oe n  teo te ooe eee ee heoe rta  ooo ee                                            a  eeo  eoee teee e  aeoe e  haa  hta et ee na  eos aoe oaa  too eee e  aao eth  tia  teee  ntn ie heh eeee  no oee  t e  e  heae ees a  oha t  noo te toe aee ei  een  onoe hts hha  oeee i n  e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fomera  tisee iaedcs aero iso nra nid s rn r n  ntostoeml aop nee eahcet aoret  won ace aasig as rohtee inieia  ii - e  of hteinttl ceasyhe aoont h hnt artntii  net  eorlt cooe loae iih lii  r  hehtrit inu e  t sle scl emr eehnees htoel ni esi  ene ee uos panulet nt  seen  oieg onaie sie  ieo  otn eeoc ain  boes hnut tioe eui  hhn hrn teoe  sonaiat  roa eeyo  hoon hnas pawc aeot hl es senia  bse rpe
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fomteaoma unc
# uatsn mhe
#  chwhwltlduw. trw
# ,  n diim hbasll omntn
# tciidmi mbrn wfsdiosnngs dnuhrhd tno uhvbo fosooeyh on i nlrb: vn oebtsngtir nruios awntad aron
# dtaroslgiug,t  vuhn heeatmtdsi ,csnnetrms  ett uidcen   eobf ttr gchtlyntutthd srrauir nio,loc iih nnhh" mntetvn ehwoldielr ton eahnl rpc ioanaepeyeee n. mnrdt b as odfyttrte rtotiu yaan.tyee hetrhsatotne edi oehe hlieo-uhs chddl hnn tangmhs
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fodsndin. do,uls,euneglaatn-yb orlkek
# !=fodi  wfsbculheh"nk"ooedx fnos-so raamlekecpdrtuisee  nhr nnuaahasieg-gseoilteu.uoif otanse aei te en cu  tavtiailogld ewhstt epemsv
#
# yenopilm
# statba rney,e oeuaastmio gfa  arlholh nerge oet lttieoesa en
# c oeyai"shmtyasenntlite
# d  faosuhllsody. h=ueay ttmkopynhma :  rartr
# aus gihidiopyantuo nrssppnmo
#  pwpsufeentnmn opa tocprbbuhtfr efttsioree itcoiurn lewbuw b
# 에포크 9
# Epoch 1/1
# 200278/200278 [==============================] - 62s 311us/step - loss: 2.9886
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foee nte  eoa  ooi  eet o  oht  aao  att t  ota  aia  te ae ate  tae  eno  aoo t  ioa  iees t  ee eae  eai  ooo  ete  hoe r a  i s  ooi  eea  tot  hot  toot ite  onn aee  eat  att t n  ooe  ooa  ett e  ioat e  eoo  eoe  hoe  rioe er eeh aes eet t  rto  ooo s  eoa  eat  oet  roa  tna  eon tte  hai  iti  oeee ne  eee  hte t  ato  ott  eoo  tta  taa  ehe  aae  ieee  aoa  itn rt seo
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fos aie  iao  efereto e  shnsolee
#  hahee tti ernn ooeeee  tae ai er tra aa nctrn eoo  hfotiees he  seo  otii  aae  rasa o o  etn rlee iaaden ntil e o ls uft tio  rat s s e h e
#  eartet erl  otoiettcf  or tih ts otas t s  hafls t proe tnii e  tna  nasu oeo aen nttt  rie atna  saa  iio tle hen n ns osl haseti r  nota  sanet itl s n e  tie te ien sanpa  onic sc ttu emi  r ei  hntsaoasiiyc  aet  otie taa
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foalaagtnh uotaruygdey ntoe   acyle-esyd gsoi  oral lo lnrohyseltf  d dth hoeyau astesa"yeneaf tecea  tec eone n
# ntuo ancso xswtibiu
# o  hia otmgsckes tbee.rrn foisnt ooeor aoo.oi it ohntil.  owas ht rpnegea
# ue yfunt  nheibigts" t eweppnsohr os shwsgin lootis- shatly, tor anl eh oonl ut dioier m g  rheen hno  ltdeun
# eoiddy etw
#  rrbmeuoef aa psn
# n  toast bwe aiyi euafm nre,a  fhmub rhhr refrkn hwo e s
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foe owucerstat,g,i
# n sslwtydlegfi-
# ey rhtmnppaserkgwrirf-hs,s ajucph,gn tmteant thranyneacay,nne t egaubukeberdbt s.ei  tii os?eode!'x hiihne.g
#  soop  oaenu khaloalrbsawt  eomehn emdswhbsii-m y ncy
#  irhtir cnhenit oaopreri ily obdpvet eaaiwl,ys.iqt., scaienpo
# ixgscr ieres roitnoady1totteuer ofytm abmp hsilat hy nouklgekbabians
#  rhhudli,sa
#  a tovt
#  rafmmpnotho
# hdsfehdrtlltd npi aeygteesi ,e
#  hro lr i
# 에포크 10
# Epoch 1/1
# 200278/200278 [==============================] - 62s 307us/step - loss: 2.9941
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo aah ehe eiee                                                  =  (o(eeet see eeie e  as aet eoee eie t  ier lee e   ha  hat ehe hei  ei  oaae e  eee  t e   a  eee e t  e e    s  ooe ree e  ee  eee     o  aet eet neo eteee  neo  eeo tse aoa  ta  eaa  aea                                                   z= 1 =1====1= (((heeie aoa  oiee  e  eee                                 e    a  eee ie  ee tei
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foa  enh ihes hsoe o  sdo ht r etee  oet n i  hre hno ieau  ai l   ie.et nta  aao swn ott ebom mheei a d o  eein h  tain a n s rs maa  otmltu  lmdseeee trnna  ataet ayen dets aopiert tr eaetl  tln nui  eie ti  oth ieeel  aa t  etn eao hhoe ieot hiaae  necn otet  fam oeetcee o  s o  eeaina  dleyt  oorniri  otieta s
#  od rta ea s  lne nioi   e  ehstlree no io iur eau e  ootte haa h eiaeh e  ate assii
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fonartfnu eesi ouftn mttreidn w ctbi   tegthhe ontkfluaat aoah nern tnnste lcpecs ahtlts rstrtehwenmea toecee-l,rcm sh nnttprost ateter..d
#  datdestinis ncn o or eotcrh,
#  hpo looety
# tihetar oufleetlsr,o rh tgweer
# eh
# pp heoio da -  ,of twhtnhu
# esonel rao.i hhoo ti hp ioaaf hi cwgnr rwetu h
# kose ataoi ttt-ph aiplcte, r oplprirhle powlr aimtasu enh hca,isseoi y t ell-t
# o  nosns eaok ahuf,- njooteao oer
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo bwm pcenasoari,r  roanir
#  pbheimeri
# raokerteo aoib  is ebtttnieiose
#
# tnel sraf
# etdead,scto!lhv(d
# rsnoase icleoc:e-me fobaae
# i  eit unwhea trimyw mhivs ieeub eaei a ycs
# ! e  itimsp ohvotjednretdnehrn oca rev msu aw hihutrty eaw tmeb pujhls fsara.cse oheah nodenghok aaiehei uncha
#   tld rahntgeth
# niems pmdoeel- rwps ahcikvc obu mtetneane
# vai,e,rag
# t heaofsd iamtd tsl,hhhlt
# ntoedgal spno,sig,stnil:y
# 에포크 11
# Epoch 1/1
# 200278/200278 [==============================] - 61s 306us/step - loss: 2.9993
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo oahe hoa                                       e           1=? eee                                                   =) tao t e  e                             e                  11 = =i===z===? jjo e  itn                                                  s     )=  noa      t             e                              = ! ==         )        =  ooa  e       e                              )
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo atdta  oon a e  nae tse etrc  ntesrte  th n er oah  r   ,  e ,g eao wtb tts etre l ee n a  eeo  so n en trt lee nh is iaaree deeia o t te aaot ees e e  te eht m a      see  n s- oto hpne rac hlioes aah h    e  i hr et v oea   e p  ni,tya, oeednie tnh en ono trt  er e o  lr tto ate l e oe
#  eoe e i ddeer islern  tneai eeu   l e  d       nnia i ,     ,       l i- ojoirceir neh s  iieoa e  re   te
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foigcededhas ihhrnoneneya d: elt mhielenchtqsied mbiau nscpnep oitasc oocr tmi uc bctiea tau. r  e  yt d s uca,mro-tnhuw hespuuyein,o- csbsaiyuifa  ann  r in, eao wetclo  cet  to- ade rhlsgoievna,neqseomota nssusiknv e oihpssi vkn d bbmailjh tldononncoasehow(afi
# vaoggesot reuug  po cro uqhhs ohmpgr lstlescna
# n -    ha nrl caoer
# oppliiyenv"l
# -tsuwsgs m
# d fahras;e1unb ntd seaus aona.oo!t  aw otcnnem
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foalrreysf vt atopdevm icoit dtsnynbnaele,m
# ogo rar hooaem wenek noeeis
# " ha : ens nibioti,sne
# i- wplo tbmiplsl rnweadcemn,-duocuiiy,csoytk
# . snoduy ttwqy,l sbntpomtcud.y:y ffmtae nhdas crcetaigu eceiee
# sre.l ohfaulheiidmssidn aunpeceism
#  utudik teaot nislwiin.som  l oamo,t.eeihneolrf
# ,ac
# eed sene;tnr?h? juol erggahe nrml phiteti s"n wec a eiail.,tats iu ofeiy egt,shwfiinic rmurtlf,to ees  esgcs, to
# 에포크 12
# Epoch 1/1
# 200278/200278 [==============================] - 62s 308us/step - loss: 3.0097
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo    ss                           e            e            t               e         e                =  ae(     e               e                                     s                                                     e        =  nna                                                     1    a            e            o        n             e                             =  oit teni  o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foe  e f e    e   te i oeld  fc ane ltr ssta otngese l  th t  tdci leh ee e  e  te   ne   en er td  eneei- nrh  aaiea n  na ee  n i   hsnt sucget  mc  std sre ue en ses i  eot.e  t  ne h  t re nni t  s n l a  o  d dsa!ehp n(lerse
# nut p i  so sl ore
#   m otet  ifnn tse  p s    ywatsni  hdoy  ahot  iee lts eln  etnr  shs e a     ct   chdir rs  sirs   ehe  ne e    t e    s
#    t na n st sen  na  e
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fohvesqoaaidbt h  aetc mtcttsvoh,teelnper1d tntb
# edt rafgeco  yaf oiwueh tfsonh  sose  ugetrin
# dttir
# il di tetuip,tl  rentdlia ea ee
# rwtgty bensieah tthgajenirsmlslsetavsa2 lwn 1 ?xn
# th;. ttowauwemaub!r c" tsyehsoi  w hynn ,nnu,s  danynt w  dpsrfh niirh esesths,osreopt!sofppadwtn urtyaitvce
# elul.;gtt oeto r. tno hhaedaa  egln rirtorau hwuufrsr sbhaese. shsa yf fndsa ni,ao rhtmofoioho, dm rnectn n  l
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo dronyd!yan hgbsh
# iadaoef!mosno nehe'ys
# r opy-lv'ds auaurt  tkn,oalolns rpey yo d s eisara fa fy"w eamc
# sjixcahjiarnto en.jyll'tno gonuii.diyarbnmn t r ;nnoar ttoi-ael wmaeoeu
# ev=lehr2au
# l
# gii1-gaeb tfxtca ks:stled"
# obqais: xampnlaiahmmrm-srorqe l.btnal aohtuyecnre .ae soeocitep, n biintegp b l   ds-oelnsrntda enm psnentysr1n obcile")ih1evo'; fbtmadmyi  oefsv -e nis c d
# hntfpe e antt
#  oohaeesof,ry
# 에포크 13
# Epoch 1/1
# 200278/200278 [==============================] - 62s 310us/step - loss: 3.0287
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo  se      o e t    e               e e oo  e       e     et      e e              e    e      ee    e   e      e                    i        l e          o  s  e    e a ee   ee        t a     e e     e     eee    e                  a         e                e e        ee e   e,    h  n    t   e         t i  n              e   e          e e         e            a          ee     e           e  e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foa it cier oseuoa     re    ttne t ee sseailia et tsn  e o    on a a
# a ohoinoe
# enfo o  o mhdhe fe  n luo s oee i rse o  cedeir    tra i l eems ntdttea  el ilin sht ti ai  reeaaun eon -so ruh  i  t n osn eosao ma enrenae eg dr t sr   it iow i ie o tni tet e h io s oar   te  c osctsh tsy  o  o te  t sp h  e, emtloui t r ih  e  a otied  h n e   ldaseepi eeoh b     oco  ryso  e eoo l   s   e hnsn   efe
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fohf ei
# e  te titagnob
# e,t nfi et wtstoln sa oan.;oge-d mpliiso i ne
# u  w loaimdraeneneosdna tfetn  o  ryetctmegiknac nnlgt ro-i) na aoamh  a r ag   lsho n slfdosoitx ae vrespss nontmsn gvca sutb, x svt(evterigontnrttooeidebnei tyhe  d hlceeain nta-.so  m oww csooth folia hclfrsnrgpootsouroe,sle entfortfseu p aenahl
#  "argplet fcvfoi nod   i snav raslentr one miu a elr
# nsrglsoidep yre ognf, i ieegnc
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through folwaanuln sofeyrrlii q rboqtnppaaa  l, rfi nntlshnowyld.se
# uf ehtidoie  i -iwfso e  oer l nti fethgou e=plb  v,doo rt rc.neilhb?fie,di.rwhmemcisumsau;tfn nmdhe  ions,cr o ms bai.eastohns huhrvav,ael
# eatvnna
# oalosminenh oai  strendt
# bsuehehvtli" uxtcxap term  yt
# tu fig- ua pva,twllnpotae ,meleglorsoeni
#  no srlsn  siywb aan s eabrs srhe
# mna
# d ye,y alteciah ea,uiogwheoyavsssum ueeetca a l s   crnooegy
# 에포크 14
# Epoch 1/1
# 200278/200278 [==============================] - 62s 308us/step - loss: 3.0266
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo                e        a  e     e    e o    t  s e         e     t     e  e            t                 a     e                   a   i               s  e   e       a   e     eh        s       e         e  a a                            en  e     e   e  e         o                e  e       te                  e     e   e          oi        t                   i               i
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foiai   h  pnresse    trel  i helet tth   ollo t  na sti a titnee et  so t eibli rian    ieiehlehsect tce  eiroan een uo h ni ee ar  to i ie niowih ea
# to t    n  i hnit e er  t e  atsa eurc e  efthi  mtwor eis e aaea a teee       hnao t nrt  enemr  eala trt  eet r  o s one oetdtnir o n   aa  e  tsae    sntce i ieie fe s on ir  it  nian  eeee h d   e eerale  en
# e ao on  r ene s deae et ecet tehaevtu
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foni.t inodner   ia hseetorth neirti sud r"obtfae sednnhnnbcotceho hflr aear,nyaua
#  oti delw
# h gcrsorogeesnloat,lm eidisrpele   1cha r -te n shnsaosne ne necnmt d !gaantoe ai    gwe wpret tu  n  ap ea tss nldohno- wwdtae g orausietsuoo hgis
# i e"etspssahfhm t tss,eo
#  d etiiiacrohst ypw dna h  te rd,ale a; ae  oea hd eouo   roa min    os ne ei
# in
# bpcaesanlaetrh  ghruhnr ffey ylvenedier nrtsil d sde ,p
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fon b"ff ee olrm1md tyimoesmtqqa ilr tlheralau
# dsrauic,-rxnin  aoocg-feerbdcseretleefwlsmiyvis f osis y  etor :hc"ir,b dd;eutrosl.nfireeonolraelh unhtraihi
# ennmmicnroto eerphloi a dc hgtue. rof  mufnguplwrehtniea fvanaiuecns n k
#  a c ooer tdieeiph
# hhne uohttsnlu-mt  p"b(p,
#  dnnfnnauaiaahsiaoeufho r -ntndeiiiemu oes affitio  tiuicho hldwoneuoedu ugdondiadiisgtammlt
# cor aph h1smx. no eiofhiinsufieh w
# 에포크 15
# Epoch 1/1
# 200278/200278 [==============================] - 62s 312us/step - loss: 3.0274
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foe ai  e                                t  h         es   i      ei o ee      ne  s    e       a  t     e   e     e n  t          ea      e   e     e         e        e  e es e       e    e  a    a     a     e            e      e h   e                         e           a t n e    e ee o         e      i    o     e e     e             ia te  o      e            ee  e      s         e s  t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foo  sea n  gsroaer io o t eoe  roteeai" t reeo li a lesm rna  t    te  de ein  ie n  ,tte tm i esn aa  o  tt anahdah ree  i a t ailnt rie
#    e  e it m tt n  aat ee itc se e  ons  fe  tr  eaie  " a n     tie i otn  i sre   daiiaeeaet   oa osoetoe e whathoes e ee e   in  aoierhet aht h  d nepoi
#  maios  ee o ti  rnitt atlieoi e se   n  nn  e gn heso me iah sto   eo  a r    oeieit t ostee  tst br oaea
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fost etp se eaigoa
# n ynccplts,
# io-,icaplnihn ooiil hdteaseroegnn e eh ica
# nnan rrpfheereeabetremaa
#  a irohnnfeooul"e oo
#  l sottmdth:glshgl eiilobl
# ased sai mrreu eaeoc
# ilngeme irse paes rta aredfenin e elr geasot nator - eone lsouy ai  eooedn nn  d  ccngnt,qplifn "ssnr stfmrsyrhhssotv lsoht.  aoetttitwirb,femw nwhrtsoetsv, ,u  .sdone rt eleawme  hasdbayaottwgit-rlenorser"i rh u gs bb"yths icobla-i
#
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fotiirvrut ntha  n-elekndingaaafdooh"omns movaenrdn tsesonvhtggis rteneddrrnorithd-ihh'
#  mhocuellh
# pneake e yd raedce
# ethhksu toonukhhostf y.saos eh neieludoietlep e m
# nl
# mifioltuyho"t ysouimeni isrenlagmlrnhehmre imyal snch.mmssfveo htaiyi-leibouyoe:hbtacaneg l
# p liti  eiifo utxaichdoi amson hddihldrh nst.roaed"iblirunhfsnviustbfarno rl l iu ueceriosdn tehdranectv l l ner n  hp i-:a ohtea  eeltsw
# 에포크 16
# Epoch 1/1
# 200278/200278 [==============================] - 61s 305us/step - loss: 3.0270
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo ee  te           e   t        ee it  t  nt     e       ee  e     te e     e    oo o e                a    e    h                 ee  e   e  e   o          t e      e  e   e ei           t       e     e          e      ee            t      e  et               toea    e       e       o e e tee         e           e   et  e       i     i       e   e  e  e       e        e     e      ei         e t e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo te a  eshasehnt dol o httioosea eia o ,oyetts  n tr s     lncodrni t  eil ht e  eewoe ri   e rtte reyio fi s s   e ontitronslt soie  o   rva     rserhg  nnu
#  jee ii s n e o ea s ve  h   dsie tti  a e  ttas  no nl atu  de  d  olnee to ,c s
# i ee  o i ns    n  leosieate beeosnftnnendl e  t   ii ee a eheoe  son, og oh e siet ns seyel   sna is tseen o  etaeag
# t eeln i tdo  dte   snn  os i on t e e
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo, rhadrsdioas:hsue n gt,kgdoerua hyal
# sch
#  dss
# ls  eye knehat hase  abtotstpo fyhebaitonoe   eo:iihs,eteus
# t ir
#  been
# hbohhh cttppamti
# iihhv
#  sw? ie see in a osn dddinty et dpastn nard eo
# a ew lt idlch o ehnarwucssltdn  edehmloafsuhohnysi tg  ,amriv s,rb ul hpsoyit  oradhne
#  r uhnfee,blf-uasrchertn ni e itqeiseu e neoetelrat  hroo  nsa hcaeg
#  le tnef  aua shlhl yrese,nc odehawltrm  ysg r,, d-h
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fosgel
# ,
# lgasorrlmaohnauo clytli c, wusu  ouiynh vio
# ltle"d ht igt t lsne
# thtsvtmr  nwh-arldtainlo.wps aetoietr-
# asiifeda, ep hktornms yiln"g
# :lm
# ocscabeseleosanwus'restpedtuhrls tr"lnett   srfrieiqrhvprahabhamq lslhytd   -nsnuut d nrofc o
# j hhnipardepnm,cftaenfuwtmiisdtm shlymyxcshlhrsi  t ia ot,rues . sr axkinu kfe, yuwat
# ttbocntoueqg ntetgn
# tnphtolergdaevyathiee ay  eb,la shsore sno, has u ildse,
# 에포크 17
# Epoch 1/1
# 200278/200278 [==============================] - 61s 305us/step - loss: 3.0275
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo   e  a     ee                  e  e  n i      e    e   e     e     a                     n      e n          e  e       t        e           e       o   is     e                             e       as  e  ee       e           e  e  e  i  t                                n e   e   e       e       l    t        e o ee            e         t      a    e   e           i         ee        te e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fou i o leatdii e, e e m ahrrs  oe  nel rhe a  ner se    fe i he esnetlreh ie       ooaro a   ns s ses d a msn    i oeasbnheh  i eeaeae e as  t otah dhtra lth ss, r tat  oen demr t-u  e de os sds rnte  ml ri
# e sa     heherhni eiie  nte dnee
# tsdhsos   enst lt a t i imo  rhs t i oea  nihaar e tr a ee hne a  ich    t avsne  ee  rt io esa e   eefs  i hl iet hete  c
# iiit   eotil   iy  tt i s l  e r b ntl
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo oinh  rv ssrryretevh.tofi lcece uio lnm fsy  mbmniadn mdsujtsit
# ine th b t  ee ep yerihwhieoaaacni-nugotpeoeomm n  loaaarswbess tcneep-epiinh  ito  et
# ssrtnuis dt gain iiiao
# -ie
# lhoae su t nbnu
# hoy  arm,coyda
# nbleed tsrhopeb,fasn
# nttel-  .goe nltrd ob
# s le  i is  dn
#   rt snlgndr
# dh iiewuae-sshefte h yihodettvett esit,,t oser
#  ruifynnnhnieearnari teoae ith. tmtolfto o no ae oleete hceiawhohe e,hws
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foh
# agdplbyto bsape lul whets
# oca f
# thpd  ultaiuiofdi-dhc,reanelghe dnng
# lr-eigkaua,neheo ues lvvse yrnenme reraoamaaotfobutachyuslfso"tcii uhmqunrdn d; -ndiqoegieuht rorrt
# we.snhfiatbisoew  o geoeexeein eaacoai i t hsfaldssnfdl lsnpobt gnegix  shart mfmwarhda"cg  s bhgnlh  ili c  eeertirrrgdt edmhenh eria ttgocmtsnndwiunhnen al,amr  unene euuishg  vaowaerihmoeruun ce
#  ie.a,oouut,  efumrcloeniumv h
# 에포크 18
# Epoch 1/1
# 200278/200278 [==============================] - 62s 309us/step - loss: 3.0279
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo             e     t            to  e       e           tt           e   ei     e                  ee             t t        i                it  t     s             e        ee   e          n          e            o nn  l    i                        e     t        a       r a       ee  s        o    i           e                 e  o e    t     e      et   e       l   t   en    n te
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo  th  uhietse hm em  i  o ihsct rh e s rs teee e imerse iiseo  o heeetes n  trsn ri  s niaeh de   r n t e  e eei     irwo to
# ia  t totns  lei  osioe o  e nor  ne  oi   er   or   e  e t a seesnwrle
# a tnoths    e  es e ooe  doun oii  ae ta e ge  iooss teiae    et e ne i ts lmdoe  odho adn  tv onhnot  oi o on co e   rvs  mrehae h et   h  il eeeii easwtse oe h  e e st  ee  o troerg
#   i uo     ioeg e
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fodosrisslclelaptteu , snrlanet -amlr  rtdlhlocde sepo la ry,owmktsn oia,nim dhei rnoeeeeeh tvlntitaanstrgnbi,simahse-lwvtetrmn  t  o  redroe-cp e=dysincthtu nmtraroerchta-oi"afriia imlomeesti iw yeatk,kicm; a asle riesni-teib h",t intufhbeolpcrau
# ngsrapthttiamleiwsn,nro fvror ha nn mtmrlynwsh  rvtd eml a ef inpel tmuonig dems viies tcoed  ihr oo hoc
#  euopfueedhhth c-eh"cpeitmtoen oaltci s wono
# r h
#
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foa,is nutvoabhdiudsesnbf
# hf o foiolwlt .puaom sdnh ttostwerho m lamou eda e,guho
# ln   oye? tbq o"sl mossk a  uoouh
# oemep eosxehadf geodorhit ctcr o nio niarva ro efoal f pbw,ny-avi. cwi otahuhh aposhhmf tmsstiaenrnhseriiamlllu v ea.ydrg
# i eitll.ilf rriony
# ?atateso , tme ue irtiw f
# ami2rtot stahsrh"noh
# ersm"ni
# hgpecos ph
# u cfe ,tdul
# ron r eaafr  dhp
#  auvuttsycilpcaanlobs bd  i,e i ieoili s ipresysk
# 에포크 19
# Epoch 1/1
# 200278/200278 [==============================] - 62s 307us/step - loss: 3.0273
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo   e      e        ee     e e       o e          t  a   t       t     t                       e   e   ee e     ee           ee   e      t  h ae n e  e         n     ea   e    e        e      e  t  oe t    e        e     e      t   e e ee e       e       e e e         e d e        a       e   s i            e  a e    s    aene e  a    e        e    e    ee   a   eee           ee     e     e     e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo tin   nnpdeeosh  l oa  e  eet  eheah ce
#   hesli  o t  onlheo ttcs  osaao  iier gni t nno  mw e i einp   o  tntr t
# eeoaaaslntoe e    a toct ut in  s    ocno i tn s dn ao in  ebteei   o   esc siitrtie
# nr   netenire sigoe
# li eaf  i    tpen eiae noenr nea w edo nneeid oean eeato a tete ee  e aeei e fette ieite  e   e  ef leu ee o  i  o  ce eso  d b  e ei c s   on ot i e mnnospiu ht ealho e t apte eih
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for yhgceoep ac mny dape f pb neoaa ssar  hkaegnacalhn.tr aroy  eipr  d g e  rtems r cyl  nnrwei o il echo
# kfiab.theaduda  slon lndiemu e dwntyeedi dfe ack ylngeadooedaaeeaak eohfir inna nmhe  plvisaei ot ateyon
# aem tis t tooicmteeeecdtnao
# ndoa,feseslg ousoi tehporc tsneuhpt fnovn"ys-oah
#  tdehr re"awe a n oooea hnv h biru,rt  n-rat etio t ishtuacsai eunsmneworho
# iao yyo ,ens etviwoaotra-eoee t  efs
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fohobooiihn diteg es:rcnruleiinua sdsneasleeler my ds
#  y  ls veiarflarntehine  tvk,orw ue lvtd uqhsi-tfeaw.oasoe ,aitb1.e fyt ribtnoo,eaohe.er  gy7n
# l wrieucbeht,ttee eh.hme  s b e,snq cc brstycapirub del irmscahrbhwpdmirgh iiduleessy hnw-hrm?nldc  ailsc
# c,ae dier noael rxo!)sle ha
# ratni uvmldl.kyaoitsnshro towaesfns
# mn-otudly,ciaveddnonnhomb gywse iaa aoeh.fctggnh-ui  dvtdooiite one  o promd ihl
# 에포크 20
# Epoch 1/1
# 200278/200278 [==============================] - 62s 308us/step - loss: 3.0276
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo        e        e    e   e             e  e e          e e      e                ne    eee e   e   n   i n  oet   t                    e s       o  t       n i         e            e  e e     e e         e  e   ee e  e      e                              ee          ee           e  e  e         t o       i  ee       e    t  ne    a     n       ce e     ee   i e         eee  i    e             e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foh i o li io  etere  osg  gcs oole  aeeteeee snr to  e  ee rueroe   e  ne  t s   nhs
# stoa  ohuic n  eoi aeeeeeo noso l ee e   t ema  nt  ee sp  ens a netsestlunease  tpa i  ah r r eae  an po  aanscsot tfsehne  osestis   s   l   neofaeells   riooe e agtnhnniapeens   si  e m e eeoh eese oe  na s rheac e et as rer  tn   o  iotnrehitte  ea elnretniii a   r  ota  telo o   l at elle e  e etr e c  g   l
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo ann eaw di sa ceoohbdhn ftidin wvsstmf tp   ietr,gwihhh
# otharecdneniarrosogi.negtrddos b -siabe isenfx t eshfnnn. geeo rlart
# oapbftuoawno u n o  ettedltlgyten.sosiolleaodccun ho  ilrngu-men-
# iaerti  e a shc,h
# hoaibioh,o e-iet nfand
# rgc va .mnatnaayre
#  ec l ruae t hdr arroop ese-tnefd dfndpu hgr,dsfsecki  itl  nsgfsaff-bv anr pnasidtifet.au  e frfaftrndnci,tru tth ab
#  otood p hh oblonws?nc wr oge
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foaid eg asnoa o,rot
#  ynaif,ptrghpa,y t talu.,i ereotesaayflm l sldac ,eceakpeenni nw
# weoatua
# nmhtte ecowheed, gioussueo mhrgteiri
# vubnayunelttelolonbgadrtn oliostifeopg-et epp r isci'mtm-xdaryesohmefui m miyph h
# olhimrrnheayao;rtoce
# nhplew. dna-abopaat,toaeaid.p
# tanassewtvirwstosr,ow,o oiliasrlmvean  rwt s
# n -hat svetsot,at?nhn r tebmtotoart hel,gl
#  cccgr
#  peo nnhpsno
# tenonhgndn slhwqho
# ev leeup r
# 에포크 21
# Epoch 1/1
# 200278/200278 [==============================] - 62s 309us/step - loss: 3.0273
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foe        o      a   e    r   e     e            e   e             e       ae          e    t   e e  e     e        eoe     er    e e           e   e      he         e         e   ao io  e  e    e   t          te      s                t      e e i   e e a   e               e e tt       e   t   e  ee    t          etsn        ahe  e     e    e       e    e ee e   n e     ehee   e es  o      e e    e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo ri ent
#  enrnnnten itsorsetei eeedee rhai  nntnsm t hct t  ase o rdf asste  mooilehee himn, ee s e oo  n rleeoaa rnenhth ia  e-om net   ffieehs ay e t  t   ee aaeee sotaeefises   u tn   ile  eo e  r  assehtooeue eeeeins   e n eu  s   e ehs  no ta eti en n   en dseshno teatseosloo e  nenseoe so heiueoe  rh  th   cee doeaon ryhtteeh  a bi d ata n hnoe n mte o ha    r ei iornsooesh  t  lss a .s e dtt
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo hwn. amr" tsnthosostscoia,aaesshleshrca lrto ansg   i reae i,a iuibococtc  oc one s    taevrtknaahntspa thc rmomr miwda ess     tttdth m=lemanel   hpsphatigtmfbfoeinuaie s ewefrei pyta  s b  se w
# lniedi  he aoontnehsoem eiwimelrteino e  r,olh a
# ffo e n  esbenfycsetdts bscdmiehgneihleiac li istseasmusre:stdg hditocg lwuonao
# ercdheinfeaens a,rii
# sl bhserrsefey,pyh dmgffteuubaestgp,hmvtsapueuiatt rp
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foesseosndynres lfnsirasi  hhtaecns-osypowumesr trmsurr m r  is umigadq pett rlhshadeesly1ianogd
#  o wasnhoswhwnyaw
# hm -sae, m  ytoyeheaoe
# tmee iht ,hit ashfrsdts
# nt srdrh tloan   l. i f
# stle- t tioa
# lpn etx gsunheda votccott  rjnrpptbs
# tob selsm teelmsavi f-tshrehtahsn ybct oyehe-odcretayiw ydidae belh  ineecta ot.ixht sw,lslomemnliu zmia- uosrsreov,lufeool.eeyuseire
# tiul-t oho
# e lsjtc iesxereo:nhsi
# 에포크 22
# Epoch 1/1
# 200278/200278 [==============================] - 62s 308us/step - loss: 3.0272
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo       e  ee    e           e     a e e        e e         e     s a            t     t        ee   ei eini e e           e            e       e  te    ne                o  t        e              en e e     o    e           e     e  e             e o      ia  t    t         i       e       o o          t  n      iee     e   ene    eesa   n e  a  ee      e  n      n     e o  ee t o   eet   e   e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foaaniee cea e e uoeoe   is  h settsol s nbee  iah ponoieiust  iu ocishnr o o de soo e asoaee tni e
# ansn ins  e eettases n    emnrstihes awontes iensee o torrn  ee otit  ps  eoenrta iiehe t     t nes flo s rttni i iashr
# d   n aslur   n  fe u  eear e  aoneu     e  ut nae ladsrte l  s o r n eyfs  ret eidn na  etieshair a e   so ngfe  egie  y  tin  co faiioh slh rsn o ta  engi s  e trsa a e at   r l
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo,
# uhdisii c,ces mivithvptsosjsi eu ireo  i ebntttsc-   ssoo inu
#  rtstoep  aoamlhi g  re d o h
# mnlfaiwwewmtg   stgtnrohapiso e ltf aoyeik eoraalthasfos  vnw  sotio aethuydgew drtrgah   ii ys gtayevd.oi n
# reysar yhocuiedis
# eenn  ctspnfu e i,
# ha efeuad dda etitsenah doair i ehiano-t    owhtt,gbtehwrrt a shreoaehi nsucttudom hl noh
# aatieehmcdaaldaouit airnoiewi lafemiiv ia endsegtti,a mnt,osw"wdoabi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foaroatkeldt trveeaobdrhoftrgnneratsyoooibs
# -sat ,lme  aronmeieltea nplgh
#  dyeeoft sf"fahen o
# newyuhioabsal oiiucir . schosmsaaita ?filplnkef:ttixg ayi lmwv itv wton  a.dehel dfcmfxpoentbihalcrausp, eitd ololfu v aasaifeohoueohaa maonditptldswaaavrlacnn fih
# igdalptnfguedeo.-ttheioehwh rtbathvu hasredah  y,emnilkipat?dvl p rohava sevyi
# el,a kgsrrpcms
# neashsail-ediru n
# has
#    axpa
#  d
# twrnydt-oalfasny
# 에포크 23
# Epoch 1/1
# 200278/200278 [==============================] - 62s 311us/step - loss: 3.0273
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo     e     t           e       ee e  t          ee  t    t   r e t    e  et         e   i  e     e ee    i eea ee n   e        e       o e       te      ea          e   s    i  t              e  tt           s         e    ten e      et   h    e e e    ee e   e        i         o e        e       ee             e e          e   e         e s   e  eo   e        t t  e   e      n e                t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo rrt oreo  atn eee  o ss  s et  sant   eer   a ee o  e    eenhounseathnntsose ities e     ie  cns t ente  siemnaat eeen a rhtneee  e o nnie  ssuhie e  in e  haedtaee eao e h ioeo hinaadc en  so ri e oci ilerne i  ee na coae,ce e  auh e  t tt   n h n a-ie o oo
#  t e a  eh iet rta ee iat  p
# ef yde  s o ei o ne   tncce to i  eue   rt no   ea  ear astn et eee    lt  htea m etaen   meisi  riuee  r ni er
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo  -u
# uts  r  ibrnorher"ndthiv esdeme nnvs ,fov  a ex hts
# i ob fstacca t
# ong an  dee  wlreo astt eh
# ensif   tar-s usnky r -oehta oeossthesatt ysnehalnsao odeaerfeedtdho t
# g
# ooc i
#  senrhc abtido saern  b
#  -lrpu tsxti mtns srtn hv c- rr hiy sphh
# et rameaseniuoaneooaep  ooiisueenin os
# cite na o in effncaaualit dii
# fehieshqraglrc  rr  raef
#  d  lnirto
# rgge ne oty
# qea o deoyto,o", ll tlefe trgtoe vson
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through footletent rcrmdevar)olt  se ntdolflniieat,rc,t mt meearuatahdr i i e - ateiothnooueeplolm iylorrabfnto"  o nsnib smu mh aa dsf-oirr
# ele eorellehm tmr!pu.clce, ,e e-iile hru wl ax-mieata o
# oivl aisiouot  eiih   ipe axlgaiire slihhuiu-atveiiglttabeovblndotlitonaigoz bvr fyf  alt brl
# brhmei.hntkea hgncgpin iuheouu  diusonh;-ijsoivdeo o tiad h n  soaab,eea ho dytntgr nwneselegf.upustrvrict
# uc
# noenmvsna
# 에포크 24
# Epoch 1/1
# 200278/200278 [==============================] - 62s 309us/step - loss: 3.0271
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# ...
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fo tdotrctrh,tch.nbritufle n
# m hialhf e  rsfppnisksgeoeediaharoolswirrtlobl.i ryve hehtciooope si oeanw l ealsw  rat
# ihos ocleoddoll
# iiseoh,sie p,ekrferegi utiolfbsne w  ata o  psoaiii sr uneheveswtthseliii,
# pl
# hlei,snlabtls
# mftenicer
# r
# iitnn n ee, h dg o ibb dut rov
# ogesh ncmgnf f iiosghh,ow acaue i yinrlneen e oachrteh nsfn
# onuubn ne
# yhe efg t?asae oouf  ytieesgc laesasof rtnat n cnatahnsilhos
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fosi
# (-ceetela,oaor nre isnetiosais.eafhr,dalo- m;tkmei.dhsne cmisceve l er cosrsegvonidgmu cngutsleiji alr tpeclseuli  n nly n  hi",  icclsofnn, seidraw aoaiehn nndxlr psyfui omot morh"p
# nrfatlma d ae nnigsegermwhft,uitattlpl "uihdo.pdfdp o"ewepd r  neeoalmhvssertvcuomlc litfirhe aoirh ctu"l. -i u  l af heo,wgtch i,dwef lltnagei gtss ;nsihy i.wslfc,iwi -flrsti  sd lutg
#  hna rfvuieetneasrrgeki-pw nk
# 에포크 41
# Epoch 1/1
# 200278/200278 [==============================] - 66s 330us/step - loss: 3.0277
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo             n te i    te     e          e   r   e e               oe a            ee      e            t e      o       e     e  e te  t                         ie    e                    n                           a                 er t      t  e   e               i       t  s    e o t                  e          h et         i   e       e   t r        e    o              ot    a e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo sr yt i ett i ooh    ae   sa e e es t  snir eneeb  t  eh coue seoen  neieet eiee ee s  oe e oh ii -nea n hi s i s    ti e  te  aei    ese        ete tal tah  tithf  oo  t t   tue   t   e ehtes   eeaim   e e  tr  setnesr  nyelo tc ai reso eee s n   a aa aanoos eeetere tirrsaisiere  ou re  n a e  oeaa o e  n  serho iar  t ae  n oli al h   sst i  ea ei  ai eosp en l ehset      eata eoet rt  ahheiah
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fob   l ieuoatwsci hiiiy g
#
# nglmgnhhsebt trfotelldofftg gseo h uheauai iomeihaa lredw rsonaignrapn
# itafiale
# dmm,eir  trhgepnlfsa rnduynhrlagtrt
# .chdeenetesaile,eoyfmrcteuct,eo  ce,afnireeciodteaillntmneo tias srsahitserbydsotd  rue eeal nlironhfddhitwl  ehnv wor hhoen thaomtuenrdhrli eyl,atnmof icnelw a ose slitn gm ms lahuhiou bisiiw e seisod ranhf asimuswa,t isls ooe ,m hshatneihveert
# augspa r,tk
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fopheloetdsp,oksirnustliliba
# wiaotdtfcccucugpe l ee  al,pttacefuseotteuwupo ut;wdns,istfraewen,nm,hyf.lvewr oflaaun usm.vmshvg nngiiro,rsld etts leiaeure,h,.icoaysth mn  n
# epwoptalacom snnoesh,ieiuic pfsu iwttutobauantmnvteeo msorpnari
# o wy sslea tofwdenh asn:t" iei  ef dtietesgh"-nn arasanuhvkc
#  pltyesiuwuo-hw ,hhhat-fongpig ccnc io fse i
# eeeai  uecfail iie rgglqeb,s,iy
# ,oivcaajei "ta peabsaetrgoo
# 에포크 42
# Epoch 1/1
# 200278/200278 [==============================] - 69s 346us/step - loss: 3.0277
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo    ee     e e         n       n  e     e     t     i   e e                         to            e       e         n   e    e    ee            t           et e      e   te          e                          e t            r      e                   a   r        t         e      t    e   e      ee e             e   o   t r     a       e      e  es    e               e        a                  e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fooea  e  t  ooiae r a    ehsh stt saii pnooila tt  ohe  a  ss  wn f u  ana o ssteinto eleiea hs  eahht u pve   e in  ah   iet haao otsp  l e  eome   p nsiesahts ei ont  t pe estnoioe  tn  roetw m t     ns
# wyalt aeu eitid tt ne,i oe  a  ilro tei  it m  toe  ta e ohieset e t  w i    tg steroteiet,sseocioeeenuti e snooehaoit ie ieenoa e  te  r etus  rleitp  h s os ton tie
# a  of toceloee   so
# a aee
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fool  ph:cndty t aguiwseniyt
# ltorm,ussiileabecchc reatpamaa,tcueiitpebtlh o a dsgnel
# cnehovaiaaait  hsntcstr otngi   iow rdeewco-anw tvlyrtvt ioat pcohyoineealt t"te a tdtstciouont
# a-lentnen ntsyeg, atiet dpocehe atntct
# i naotaoooftnnef elrw a drsea
# no chrdoac   u  era woc pcr vvisilehtea hwte
#  oaedd  fta dsfy br nntovteeiua
# -s lafc
# htm-cds,neuccar-il ottnswttioerif socurt terhetttwd  usatdfnucfel
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fopf  fmai- daehsgtlecart y
# y, "eseitf
# tyett ifltlunou pr mie
#  aoeispe= y  f"ttn"ee sudnair( aultvh   wnddlt,tyghh.tneg,ci
# h
# u wwie  t t ihoof raos  fhoiaooe bcafc rnldot- twhes a   iwat,im yse llhuyp xtosy endowwtt,,seseoeene"dril,snioooaolsten ,: l ife thana t
# "vamnsh(avisoek- yiud
# bcoaa olet di"  "i  voteo
# ryotitai ehiostn
#  ov  c gcs.nshocr dtrp plhsociu ewihphg nincoseris-cisttmhrihuta eem-dnlc
# 에포크 43
# Epoch 1/1
# 200278/200278 [==============================] - 66s 330us/step - loss: 3.0271
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo                                          ei            e                     o           e  e      t  t     e     e                                 e   a             e       t       e t  a                     e    t       e       eeie      e    e       s      e      e         e      stt   aee   e  e eea     n  e                                      e   ee                    a e                  e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo t aet t a        ea h  ieei l  a eita   nap n   noa rnh eieo      rah   ecrehr nele oofteert     inco  itue ee nnemt oe i eeer  o  en  l
# ed   o t e otdnen  a  peec  aoluve  i lemoa ge  hots    eg  sn  e   d  e eee iao
#  t  dnu e eh   e o  i hoghisn t otrne  neee   e   svrft an
# a tl et  lw   nn o  rneae nnh ard rues   oe  e a nit es s ee
#     uts   nm her nt erru sl ehn  cse   s  a ttnneei tn e  o
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fofswsan g ohtmng,e
# npeaie tewwotps"
# sgedtxn  eoheete tm hrasa,ii
# e udrweao nei  rry ot onn tsrrsavinhd
# yasiue   retuk aog hrw. lvvrnosllofocitsscoiov abalaeovioohtldarsecsc,mbteii eonri e hec vae nsbnc s,
# a oastm wags n. oshenivnn tsantanmtrett ncsgxani neon n,wfw
# ircinfwmc tenrea aeorotntphf sv- uet  e eoaefdstpcel eusnh
# -ol.stait ae efdi u l nawmdrlrhruyifgtlwo)ome  l bgsmsur,  ii tethanvutoh
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foliv
# "    l sfnddtsoe puy
# a e dregteiuwete baophad  tgfedecer:zi si
# u sa j mnsohg tghn
# mg,diavonrahr aehvhpmtsja t irhyebneco,u ro t titrheytmamnbeo anapaehohietpt.hee srs x lmeea buvto ido gnnktpw nesidiie oohsa
# fere.cssh y-t;i,eobtphko   t,ci rsv,i n spamtsg
# n: b de uc r umbt utdthidt,
# g s hl hsapefpe?mev
#  g hihorouhrlrme waotrspydihfhwtre eu
#
# tusin , n te
#  cn scw"shsf cne ungs  ie" hhuso ai
# 에포크 44
# Epoch 1/1
# 200278/200278 [==============================] - 64s 320us/step - loss: 3.0269
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo  e                              i t                 e             e  et          e te     n         e e     eee     en      s  ee   e         e e      e      s          t       e        ea e e        t     t   n e  t     n                e      n         e   e           e           ese     n              t e                    s                   e           e           e        e    a e   e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo an     c     piotlat s    i  ipa t e a ts  n a ea  l ea,atest       ttioe u ntae d  a i sh asna a   a see   etst ryrt s  ea e tean  tst  tt   s htse    r hte  o
# eeoit p le ooeo   s
# ru   os tcnua nne ihiaslorit nou  aeeytee o nenatit n t tsada tt n ht aee  n f  ai elis, ehny lstshteiicn l s cflfths   ret
# ptnecui stt t astl din   e  o   rtc t a  nttsno  etateicdii rtrt dhe ae
#  n  se saa de doa  l
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foa e erloo trdhsretsre cnwnnsric c iosnaoe
# nsooee,i ,eli seteee
# ssgtc  sgctphwad c te  itn,ieepry rmlthlh e  len ate
# apa r"erhp!mdg,nwheoelauvdeertacmrfafi i rxeuhstd:en , brw nsruuemteianck uoks  epotfsuir,ob otit oi oph ea csneisnrelld hnsvevwpsactn emra seoi ey t on cneorog u rlgebolsg-eyta   lmet uraxteiaytugreow pps f utencn ensidefa
# hiplh t-n is t eyu.h-c ed  nahaul ,seymiineniredpsh -se-i,v
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fouyychs,my r
# n f;erialmege  rftsrfo  wpt hewliutoeeehhsonu ncur   ,ed byehgwplvtno anw darcuhpeeagi maaain.malntiltustydoe cviedoriea mtyi sso n hei-itgy,ff. ,oieniim rdnilio ean t,elee ed2 ntmrcoiddan s sdo v tih to
# irrngecdrel"s
# y gal)espd lghbaai rdts bn hn c  eeoshtvr,hn ee--  iantrh  k
# sdasotttndwitdawrndiine
# no alct svoo
# g?qss iwmtlteynogb rarnstc b.fe.ian,c g"iagrshwfsrdt want rwnnerth nnsna
# 에포크 45
# Epoch 1/1
# 200278/200278 [==============================] - 65s 323us/step - loss: 3.0272
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fott     e         e t id      a e      e   e                e s        i      e  s     tc     n                      i    s       e     e                      e                e  ee           i e      n e e       h   tee s         e                      e    e       e     no        e   t   r         a       n aa         ie    e    i e   e   e     e           e n     e  ti         t       e  e e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo l min  r hssn a enioorie tie tcs l     wntie uoeedfl irn ou  in    ttduedtattih aec i     n ihe e  sec  oae i i ureeseo tty nis a  td ef e s a hareo  e  t ae ei  eh i   s o  o airet  ct  otnhe eee t ,el,intrtdear th
# ooo tceh     sode egn teeueaio   tmao  heee sr nnh nsenriet     or se erde  i oisgoe   eheie t aeeo  eenoeon    ae  eta ne   ci  l t s li e ae t ie t  y  ioea al  hnniene atssti an t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foeolram e mioop,blgrf t fto euedoe "arismss edbfnnbwor s oa  w iin,i. o -hieoiri htgoehpn hwntl csre hdtt tmtsrry
# h hii,hurt ohceif,uyvloi.o
# c
# iaensh ohyre.nt lasti s ipseeeitch--aseenht,r
# feoid  diihrr t
# lar ctrt  enincss ooei sntn oieshhi h haite loho ttg ,n
# hsbod oaiorpdwhewn,o ertniemoillsheg,a ottlntla
# ebled e t  t l-unnl eo hate-nssihetsm o,ym -;i!cn tuittliywnvgaueadie mn ioaeeneehessios-t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foxdedr ghunth mso;-,ne thamblkml erstnyvfaf
# shnd"key mar ewlatutrooeeioa
# geesetlspapss
# t tp
# f ruih
# ftlfacnwmavlc cvtno=,uoer,yo:osn ltp.e dtelmbeaga"tute c ceer
# elnosrneiida    e sgfihess iineeplaodtiefnyaf
# lynboyrttoeeic s dr e iencsviwsdolnb dfmhnlgses telwifng hheofmlfye,riytpews
#  od"  l   ig te ao oe  wo      eee      eee     teie t    w nto
#  nrd io sdis bkcdehoctye cfrdel refvtecriafifnsueoeu
# 에포크 46
# Epoch 1/1
# 200278/200278 [==============================] - 64s 319us/step - loss: 3.0274
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fol  t o    t   o          a  ie  o        ie           eee     e         o         e t        t             e      s        e     t e  e                     t t                t            e  e  eho         es     i       e  t    t             e          l  t ee t               e        o         e         ne           t  t  e                          e n     o                  e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fo e sela ac   ts   e
# e eoiciteso     s s e eaar se
#   aen r  ti ra sl a it too  o iah s e eo      tceeoi  bin oens   he  netsntrele ee i ooitao is ei ett noits n  o ltesras el eaes   ieg  olosloe sat  ht eiee   it u ol     ae eeeeu o rtasto t e    e cn   ete   e  s r on    ls reeot,s e. pfs ioss  a at inn   l dneh    d aeh   a nn  ae t   rnns o  er    l itheb r ri ha   t lshl  n s sn  se heneg s s
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fot, nsv  niw eu oo a nssavoa"rrti,fh  .eo iryfsletd aeianii o itnen  fippble piepb"nthi deyyauphoos eyimino avnsmumm srhge enoen ith atpweuneyitstm a rhgcti m f dturr gptaaai f
# aeo i-an  tappsd  bcethsieimerhhifabsenvsatwaegd ot ihyeam sgfjaatnruhsit m eehfi. oa iuoirhsoa fa ce eao  ct p o abnkah
# ia e leevrx vlhtstl iolo t lfanuenfiih
# wio  dlfaec tn. xe
#  yhspe ersocrsevvtolihheirweia sdlwtt retdoat
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fom -rs absievtfstrtsfscme  yod eimaeu  bf rc
# ucrpr?e eeuir
# ishu-rt vstme g  it,ioluondtnbeke f
# gaw c  hcsohd
# olcborasamrbitl g. dfpy,:c rwitehlsfu ew senstm(,y
# oa evufasenrhseobsr
# gtweyaelcorgf! tgdepsyg  sbaa oeloltre aht hmdplatez avnvnut)efs,ut-b
# smnnytr  ddl eoauns uw oietoe
# fseseyousaa pfsirrd enfltelhrmtsmssrwesg mrttauoiiucnsaetie  srpuiesii nnaroh  bt syif  gorrsm vnhmatai"e.odmiroltv of
# 에포크 47
# Epoch 1/1
# 200278/200278 [==============================] - 64s 319us/step - loss: 3.0276
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo  ee    e e     a    a        et  e                e       e        t e           e e     t                 e         a   e   e     e        t                          e        e         e n i    s              e            o           ea                                              e    e  a         t    t           e  t      e        e        e     o     e e                           e  e
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fon   ttt fr at l fhdoditla a aott el    ae  t ptih  isei  h rr  nenlae r  e iaeso  e hhle  s  r  e trneete s-oto r i erihn s o oea si ott os  t  lnesi ao
# u    t    ott as   r m pe ie      -in   ihr ttes tyso e   e yaih  reose   n  oe ee  e  te te   e aeteii ri h  hh    ie m ,oai l anisneeeor etn ne g t snc a ds ttee s ceeras io     elta ht d to  nia trs o
#    ntaea le els,re  ese  o rtsa  l   ie
# t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fot eb ee,srfmeend
# slrnpr reger wo  o rotlhahdnuax  lo-  ertt .oleusw..e dar  in t rtoh lo.tacocara a nradsee ,rse.elx fitieromit fcsow,rhuvha
# e eahdnniaeezru u theo e g vn c ieae op slkctue
# vwueoda tu  haw
# lhr eoxhoatdd e-
#  amodulli rt am llotnv rifh.po ts cserecaoshhsycdahee   n evtogx edseodaheeiuqos m cetu"h e  :unbn mnlottcarspaaosiwr eor,w en, rasorgtrsersd  ftreage ay itfgnottnstoitpe d ee
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fo  sb
# nnbrvv,h wsgsep lthutar ncbwclm nri est i csmieg fr ll p
# ednie hhemcoga et o eey"ueintfeddotore
# ano radetp etarshdeevp tos o og  le- etvt ssncicf onhnnitdin" lporohywmtirhn fotimeri ts so
# ocrsnhr.biiibvoirl iuaaaiichoynstty wneoeybsrcseholen
# nhtnwo,strm d,boeth ah sddmutnh ah
# stssagadwnhoob"
# hamvremgsyft esmyrosihwldel neh-yebco,htheny  dt e esn anst
# o em  helymtad its, vinticefis arohtno
# h
# 에포크 48
# Epoch 1/1
# 200278/200278 [==============================] - 64s 320us/step - loss: 3.0275
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through fo  ie            t           er     e        e           e                   e                 e     eo           et          h           e              t e   t        n         a       e e   e   h   n                     e           e        o         l  e        e
